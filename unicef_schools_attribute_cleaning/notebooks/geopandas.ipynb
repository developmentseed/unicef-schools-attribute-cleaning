# %%
import geopandas as gp
import fiona

# %%
file = './gadm36_HND.gpkg'
df = gp.read_file(file)
df
# Out:
#   GID_0    NAME_0                                           geometry
# 0   HND  Honduras  MULTIPOLYGON (((-87.42931 13.10403, -87.42931 ...

# %%
layer_names = fiona.listlayers(file)
# the lowest layer is
df = gp.read_file(file, layer=layer_names[-1])
df
# Out:
#     GID_0    NAME_0     GID_1     NAME_1 NL_NAME_1        GID_2       NAME_2  \
# 0     HND  Honduras   HND.1_1  Atlántida      None    HND.1.1_1      Arizona
# 1     HND  Honduras   HND.1_1  Atlántida      None    HND.1.2_1  El Porvenir
# 2     HND  Honduras   HND.1_1  Atlántida      None    HND.1.3_1      Esparta
# 3     HND  Honduras   HND.1_1  Atlántida      None    HND.1.4_1      Jutiapa
# 4     HND  Honduras   HND.1_1  Atlántida      None    HND.1.5_1     La Ceiba
# ..    ...       ...       ...        ...       ...          ...          ...
# 293   HND  Honduras  HND.18_1       Yoro      None   HND.18.7_1   Santa Rita
# 294   HND  Honduras  HND.18_1       Yoro      None   HND.18.8_1       Sulaco
# 295   HND  Honduras  HND.18_1       Yoro      None   HND.18.9_1     Victoria
# 296   HND  Honduras  HND.18_1       Yoro      None  HND.18.10_1       Yorito
# 297   HND  Honduras  HND.18_1       Yoro      None  HND.18.11_1         Yoro
#
# ...
