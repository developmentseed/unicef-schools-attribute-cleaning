# %%
import logging
import pandas as pd

from unicef_schools_attribute_cleaning.utils.standardize_column_names import standardize_column_names
from unicef_schools_attribute_cleaning.models.school_pandas_filter import school_pandas_filter

logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

df_src = pd.read_csv('../../data/UNICE_schools_raw_2020_Jun/HN-UNICEF-0-government-0.csv', low_memory=False)
df = pd.read_csv('../../data/unicef_fixed/honduras_original_uuid.csv', low_memory=False)

# apply country code, provider to every row
df['country_code'] = 'HN'
df['is_private'] = True
df['provider'] = 'devseed'
df['provider_is_private'] = True

df
# Out:
#           admin2    admin3  school_id                          name  \
# 0      Atlántida  La Ceiba   10100001  ESCUELA GUADALUPE DE QUEZADA
# 1      Atlántida  La Ceiba   10100002        JOSE CECILIO DEL VALLE
# 2      Atlántida  La Ceiba   10100004             AUGUSTO C  COELLO
# 3      Atlántida  La Ceiba   10100005         JOSE TRINIDAD CABAÑAS
# 4      Atlántida  La Ceiba   10100006           GUSTAVO A CASTAÑEDA
# ...          ...       ...        ...                           ...
# 17587        NaN       NaN   80100113                           NaN
# 17588        NaN       NaN   80100203                           NaN
# 17589        NaN       NaN  150300138                           NaN
# 17590        NaN       NaN  150300038                           NaN
# 17591        NaN       NaN  150100179                           NaN
#
#       educ_level environment                               address       lon  \
# 0         Básica      Urbano  BARRIO EL CENTRO, AVENIDA SAN ISIDRO -91.48873
# 1         Básica      Urbano                           BELLA VISTA -86.78323
# 2         Básica      Urbano                              B INGLES -86.79567
# 3         Básica      Urbano                             LA MERCED -86.78438
# 4         Básica      Urbano                               B MEJIA -86.79670
# ...          ...         ...                                   ...       ...
# 17587        NaN         NaN                                   NaN       NaN
# 17588        NaN         NaN                                   NaN       NaN
# 17589        NaN         NaN                                   NaN       NaN
# 17590        NaN         NaN                                   NaN       NaN
# 17591        NaN         NaN                                   NaN       NaN
#
#             lat            admin4  speed_connectivity  \
# 0       0.00001               NaN                 NaN
# 1      15.77059               NaN                 NaN
# 2      15.78602          LA CEIBA                 0.0
# 3      15.77758          LA CEIBA                 0.0
# 4      15.77411          LA CEIBA                 0.0
# ...         ...               ...                 ...
# 17587       NaN  DISTRITO CENTRAL                 4.0
# 17588       NaN  DISTRITO CENTRAL                 4.0
# 17589       NaN         CATACAMAS                 4.0
# 17590       NaN       LAS MESETAS                 4.0
# 17591       NaN         JUTICALPA                 4.0
#
#                                        uuid country_code  is_private provider  \
# 0      fc3f885a-42c3-41d7-89a3-0a5749744e02           HN        True  devseed
# 1      cd2daa21-3eb6-4c74-ae0d-1bcd2da4160c           HN        True  devseed
# 2      854f1c6b-439e-481a-b64b-b13613d2bea0           HN        True  devseed
# 3      339924bb-9877-4355-a924-464473041ed6           HN        True  devseed
# 4      5058346b-e49e-4bb4-be97-d3bc17ed2449           HN        True  devseed
# ...                                     ...          ...         ...      ...
# 17587  6189ce1a-1a58-4daa-a03d-d738aab7e8b2           HN        True  devseed
# 17588  2b702549-49b5-467e-9ec7-e75084544016           HN        True  devseed
# 17589  fb643ef4-1c83-440f-b243-5220dbaef926           HN        True  devseed
# 17590  f8a00e76-70ec-4ed8-ae00-961ce84519aa           HN        True  devseed
# 17591  d0936043-4f68-4cd5-b709-b844a0ce61ce           HN        True  devseed
#
#        provider_is_private
# 0                     True
# 1                     True
# 2                     True
# 3                     True
# 4                     True
# ...                    ...
# 17587                 True
# 17588                 True
# 17589                 True
# 17590                 True
# 17591                 True
#
# [17592 rows x 16 columns]

# %%
# standardize columns
standardize_column_names(df, inplace=True)
df
# Out:
# INFO:root:adding 33 columns from schema: ['admin0',
#  'admin1',
#  'admin_code',
#  'admin_id',
#  'address2',
#  'phone_number',
#  'person_contact',
#  'email',
#  'postal_code',
#  'altitude',
#  'gps_confidence',
#  'date',
#  'num_students',
#  'num_teachers',
#  'connectivity',
#  'type_connectivity',
#  'latency_connectivity',
#  'availability_connectivity',
#  'num_computers',
#  'type_school',
#  'num_classrooms',
#  'num_sections',
#  'water',
#  'electricity',
#  'num_latrines',
#  'description',
#  'last_update',
#  'tower_dist',
#  'tower_type_service',
#  'tower_type',
#  'tower_code',
#  'tower_latitude',
#  'tower_longitude']
# INFO:root:removing columns: ['school_id'] (not in School schema)
#           admin2    admin3                          name educ_level  \
# 0      Atlántida  La Ceiba  ESCUELA GUADALUPE DE QUEZADA     Básica
# 1      Atlántida  La Ceiba        JOSE CECILIO DEL VALLE     Básica
# 2      Atlántida  La Ceiba             AUGUSTO C  COELLO     Básica
# 3      Atlántida  La Ceiba         JOSE TRINIDAD CABAÑAS     Básica
# 4      Atlántida  La Ceiba           GUSTAVO A CASTAÑEDA     Básica
# ...          ...       ...                           ...        ...
# 17587        NaN       NaN                           NaN        NaN
# 17588        NaN       NaN                           NaN        NaN
# 17589        NaN       NaN                           NaN        NaN
# 17590        NaN       NaN                           NaN        NaN
# 17591        NaN       NaN                           NaN        NaN
#
#       environment                               address       lon       lat  \
# 0          Urbano  BARRIO EL CENTRO, AVENIDA SAN ISIDRO -91.48873   0.00001
# 1          Urbano                           BELLA VISTA -86.78323  15.77059
# 2          Urbano                              B INGLES -86.79567  15.78602
# 3          Urbano                             LA MERCED -86.78438  15.77758
# 4          Urbano                               B MEJIA -86.79670  15.77411
# ...           ...                                   ...       ...       ...
# 17587         NaN                                   NaN       NaN       NaN
# 17588         NaN                                   NaN       NaN       NaN
# 17589         NaN                                   NaN       NaN       NaN
# 17590         NaN                                   NaN       NaN       NaN
# 17591         NaN                                   NaN       NaN       NaN
#
#                  admin4  speed_connectivity  ... electricity num_latrines  \
# 0                   NaN                 NaN  ...        None         None
# 1                   NaN                 NaN  ...        None         None
# 2              LA CEIBA                 0.0  ...        None         None
# 3              LA CEIBA                 0.0  ...        None         None
# 4              LA CEIBA                 0.0  ...        None         None
# ...                 ...                 ...  ...         ...          ...
# 17587  DISTRITO CENTRAL                 4.0  ...        None         None
# 17588  DISTRITO CENTRAL                 4.0  ...        None         None
# 17589         CATACAMAS                 4.0  ...        None         None
# 17590       LAS MESETAS                 4.0  ...        None         None
# 17591         JUTICALPA                 4.0  ...        None         None
#
#        description last_update  tower_dist tower_type_service tower_type  \
# 0             None        None        None               None       None
# 1             None        None        None               None       None
# 2             None        None        None               None       None
# 3             None        None        None               None       None
# 4             None        None        None               None       None
# ...            ...         ...         ...                ...        ...
# 17587         None        None        None               None       None
# 17588         None        None        None               None       None
# 17589         None        None        None               None       None
# 17590         None        None        None               None       None
# 17591         None        None        None               None       None
#
#       tower_code tower_latitude tower_longitude
# 0           None           None            None
# 1           None           None            None
# 2           None           None            None
# 3           None           None            None
# 4           None           None            None
# ...          ...            ...             ...
# 17587       None           None            None
# 17588       None           None            None
# 17589       None           None            None
# 17590       None           None            None
# 17591       None           None            None
#
# [17592 rows x 48 columns]

# %%
# optional speedup: we know the lat,lon columns are numeric AND are required, so preprocess with pandas
# this also suppresses many validation warnings about lat/long

# this gets rid of rows with non-numeric lat/lon '(blank)' etc.
df = df[pd.to_numeric(df['lat'], errors='coerce').notnull()]
df = df[pd.to_numeric(df['lon'], errors='coerce').notnull()]
df

# %%
# apply the School validator
schools = df.apply(func=school_pandas_filter, axis=1)
schools
# Out:
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines / Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica / Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica / Media', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica / Media', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica / Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Media', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica - Adultos / Media', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Media', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica / Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Media', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Media', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Media', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica / Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica / Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica / Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# ...
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica / Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica / Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Media', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-Jardines', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Pre-Básica-CCPREB', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:1 validation error for School
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']
# WARNING:root:2 validation errors for School
# speed_connectivity
#   ensure this value is greater than or equal to 0 (type=value_error.number.not_ge; limit_value=0)
# environment
#   value is not a valid dict (type=type_error.dict)
# WARNING:root:no fuzzy match for 'Básica', choices = ['primary', 'secondary']

# %%
# filter out the None values from the schools_pandas_filter apply
schools = schools[schools['uuid'].notnull()]
schools
# Out:
#      country_code admin0 admin1              admin2 admin3 admin4 admin_code  \
# 0              ZW   None   None              Harare   None   None       None
# 1              ZW   None   None              Harare   None   None       None
# 2              ZW   None   None              Harare   None   None       None
# 3              ZW   None   None              Harare   None   None       None
# 4              ZW   None   None              Harare   None   None       None
# ...           ...    ...    ...                 ...    ...    ...        ...
# 8266           ZW   None   None            Midlands   None   None       None
# 8267           ZW   None   None            Midlands   None   None       None
# 8268           ZW   None   None            Midlands   None   None       None
# 8269           ZW   None   None            Midlands   None   None       None
# 8739           ZW   None   None  Matabeleland North   None   None       None
#
#      admin_id                   name address  ... description last_update  \
# 0        None           ADMIRAL TAIT    None  ...        1001        None
# 1        None         ALEXANDRA PARK    None  ...        1002        None
# 2        None    ALFRED BEIT PRIMARY    None  ...        1003        None
# 3        None              ARDBENNIE    None  ...        1004        None
# 4        None               AVONDALE    None  ...        1005        None
# ...       ...                    ...     ...  ...         ...         ...
# 8266     None           ORTONS DRIFT    None  ...       17949        None
# 8267     None                   UTAH    None  ...       17951        None
# 8268     None                MAYWOOD    None  ...       17981        None
# 8269     None                MELROSE    None  ...       17982        None
# 8739     None  DABE SECONDARY SCHOOL    None  ...       12974        None
#
#      tower_dist tower_type_service tower_type  tower_code  tower_latitude  \
# 0          None               None       None        None            None
# 1          None               None       None        None            None
# 2          None               None       None        None            None
# 3          None               None       None        None            None
# 4          None               None       None        None            None
# ...         ...                ...        ...         ...             ...
# 8266       None               None       None        None            None
# 8267       None               None       None        None            None
# 8268       None               None       None        None            None
# 8269       None               None       None        None            None
# 8739       None               None       None        None            None
#
#      tower_longitude is_private                                  uuid
# 0               None       True  2566e8ff-59dc-4b10-8669-31e890102528
# 1               None       True  6a4a2d83-e080-4725-88fa-4773ebbd32bc
# 2               None       True  2418eac4-de3a-426a-90ba-6fb62bfb1d08
# 3               None       True  a586e318-b564-4985-8f58-d1961e9f58f8
# 4               None       True  4d0f6f3e-f14c-4328-b4c0-ca9ce03ce403
# ...              ...        ...                                   ...
# 8266            None       True  52e143ea-978e-4fe2-ab57-c526c1f8b5a3
# 8267            None       True  986060f3-1fab-4cda-bb14-304b82ba421a
# 8268            None       True  d58c5813-2739-4249-8663-c20a0c8b01e9
# 8269            None       True  5faa1276-d78c-4273-b332-98a9bc057657
# 8739            None       True  e3837b80-73df-43e0-9909-a4a6e001e01e
#
# [7919 rows x 48 columns]

# %%
schools[['name', 'admin2', 'lat', 'lon', 'num_students', 'type_connectivity', 'educ_level']]
# Out:
#                        name              admin2       lat       lon  \
# 0              ADMIRAL TAIT              Harare -17.82644  31.08971
# 1            ALEXANDRA PARK              Harare -17.79152  31.05566
# 2       ALFRED BEIT PRIMARY              Harare -17.78811  31.00001
# 3                 ARDBENNIE              Harare -17.87671  31.03505
# 4                  AVONDALE              Harare -17.79174  31.03407
# ...                     ...                 ...       ...       ...
# 8266           ORTONS DRIFT            Midlands -19.14955  30.65332
# 8267                   UTAH            Midlands -19.21671  30.30106
# 8268                MAYWOOD            Midlands -18.84981  29.66975
# 8269                MELROSE            Midlands -19.13653  29.73772
# 8739  DABE SECONDARY SCHOOL  Matabeleland North -18.56884  28.72504
#
#       num_students type_connectivity educ_level
# 0           2390.0               DSL    Primary
# 1            983.0              None    Primary
# 2           1784.0               DSL    Primary
# 3           1240.0               DSL    Primary
# 4           1708.0             Fiber    Primary
# ...            ...               ...        ...
# 8266         332.0              None    Primary
# 8267         250.0              None    Primary
# 8268          34.0              None    Primary
# 8269         156.0              None    Primary
# 8739         138.0              None  Secondary
#
# [7919 rows x 7 columns]
