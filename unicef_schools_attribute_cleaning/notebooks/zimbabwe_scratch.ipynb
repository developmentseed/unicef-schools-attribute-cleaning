# %%
import logging
from os import chdir
from pydantic import ValidationError
import pandas as pd
import numpy as np
from pandas import Series

from unicef_schools_attribute_cleaning.models.School import School
from unicef_schools_attribute_cleaning.utils.standardize_column_names import standardize_column_names
from unicef_schools_attribute_cleaning.utils.none_words import none_words

chdir('/Users/alex/repos/unicef-schools-attribute-cleaning')
df = pd.read_csv('./data/unicef_fixed/zimbabwe_original_uuid.csv', low_memory=False)

# use the uuid as primary key/index
# df.set_index('uuid', inplace=True)
# df

# apply country code, provider to every row
df['country_code'] = 'ZW'
df['owner'] = 'UNICEF'
df['is_private'] = True
df['provider'] = 'unknown'
df['provider_is_private'] = True

standardize_column_names(df, inplace=True)
df
# Out:
# WARNING:root:renaming Name to name (known alias)
# WARNING:root:renaming Province to admin2 (known alias)
# WARNING:root:renaming latitude to lat (known alias)
# WARNING:root:renaming longitude to lon (known alias)
# WARNING:root:renaming connectiontype to type_connectivity (known alias)
#       Schoolnumber                               name SchoolLevel  \
# 0             1001                       ADMIRAL TAIT     Primary
# 1             1002                     ALEXANDRA PARK     Primary
# 2             1003                ALFRED BEIT PRIMARY     Primary
# 3             1004                          ARDBENNIE     Primary
# 4             1005                           AVONDALE     Primary
# ...            ...                                ...         ...
# 9620          1618                SUNNY DAY CHRISTIAN     Primary
# 9621          1950                     PAGOMO PRIMARY     Primary
# 9622          4571  ZIMBABWE NATIONAL DEFENCE COLLEGE     Primary
# 9623         14816       WASHINGTON HILLS HIGH SCHOOL   Secondary
# 9624          9326           PARKLANDS PRIMARY SCHOOL     Primary
#
#                    admin2        lat       lon  Tot_comp_Student  Enrolment  \
# 0                  Harare  -17.82644  31.08971              27.0       2390
# 1                  Harare  -17.79152  31.05566              26.0        983
# 2                  Harare  -17.78811  31.00001               6.0       1784
# 3                  Harare  -17.87671  31.03505              25.0       1240
# 4                  Harare  -17.79174  31.03407             221.0       1708
# ...                   ...        ...       ...               ...        ...
# 9620               Harare    (blank)   (blank)              12.0        154
# 9621           Manicaland    (blank)   (blank)              10.0         62
# 9622  Mashonaland Central    (blank)   (blank)               NaN        316
# 9623     Mashonaland West    (blank)   (blank)              30.0        331
# 9624     Mashonaland West    (blank)   (blank)               0.0        486
#
#       _tot_func_computers type_connectivity  \
# 0                      35              ADSL
# 1                      50               NaN
# 2                       9              ADSL
# 3                      29              ADSL
# 4                     309       Fibre Optic
# ...                   ...               ...
# 9620                   14       Fibre Optic
# 9621                   10               NaN
# 9622                    2       Fibre Optic
# 9623                   33       Fibre Optic
# 9624                    1               NaN
#
#                                       uuid country_code   owner  is_private  \
# 0     2566e8ff-59dc-4b10-8669-31e890102528           ZW  UNICEF        True
# 1     6a4a2d83-e080-4725-88fa-4773ebbd32bc           ZW  UNICEF        True
# 2     2418eac4-de3a-426a-90ba-6fb62bfb1d08           ZW  UNICEF        True
# 3     a586e318-b564-4985-8f58-d1961e9f58f8           ZW  UNICEF        True
# 4     4d0f6f3e-f14c-4328-b4c0-ca9ce03ce403           ZW  UNICEF        True
# ...                                    ...          ...     ...         ...
# 9620  5c335fc2-c8be-42d9-9570-85a78d59e21b           ZW  UNICEF        True
# 9621  c02963fa-5587-42b8-aacf-5d7ca490546a           ZW  UNICEF        True
# 9622  54ed8226-e1d6-4d5d-8675-6dc2208f1025           ZW  UNICEF        True
# 9623  a291c700-6b39-493a-a3e3-4d6687484b85           ZW  UNICEF        True
# 9624  3a5c4b35-60c9-4289-b24b-94fbb0372ba6           ZW  UNICEF        True
#
#      provider  provider_is_private
# 0     unknown                 True
# 1     unknown                 True
# 2     unknown                 True
# 3     unknown                 True
# 4     unknown                 True
# ...       ...                  ...
# 9620  unknown                 True
# 9621  unknown                 True
# 9622  unknown                 True
# 9623  unknown                 True
# 9624  unknown                 True
#
# [9625 rows x 16 columns]

# %%
# we know the lat,lon columns are numeric and are required, so preprocess with pandas
# this gets rid of values like '(blank)' etc.
df = df[pd.to_numeric(df['lat'], errors='coerce').notnull()]
df = df[pd.to_numeric(df['lon'], errors='coerce').notnull()]
if 'tower_latitide' in df:
    df = df[pd.to_numeric(df['tower_latitude'], errors='coerce')]
if 'tower_longitude' in df:
    df = df[pd.to_numeric(df['tower_longitude'], errors='coerce')]


# connectivity_values = df2['type_connectivity'].unique()
# logging.warning(connectivity_values)


def series_to_school(row: Series) -> School:
    try:
        result = School.parse_obj(row.to_dict())
        return result
    except ValidationError as err:
        logging.warning(row)
        logging.warning(err)
        return False



res = df.apply(func=series_to_school, axis=1)
res
# Out:
# WARNING:root:Schoolnumber                                          16475
# name                                         IMPALI PRIMARY
# SchoolLevel                                         Primary
# admin2                                             Midlands
# lat                                                       0
# lon                                                       0
# Tot_comp_Student                                         56
# Enrolment                                               628
# _tot_func_computers                                      74
# type_connectivity                               Fibre Optic
# uuid                   550f2b18-da8a-49bd-a0b5-5405a2c5e386
# country_code                                             ZW
# owner                                                UNICEF
# is_private                                             True
# provider                                            unknown
# provider_is_private                                    True
# Name: 8523, dtype: object
# WARNING:root:1 validation error for School
# __root__
#   invalid lat,lon of 0,0 for name: IMPALI PRIMARY, uuid: 550f2b18-da8a-49bd-a0b5-5405a2c5e386 (type=value_error)
# WARNING:root:Schoolnumber                                          12976
# name                             AMR SISTERS ROMAN CATHOLIC
# SchoolLevel                                         Primary
# admin2                                   Matabeleland North
# lat                                                       0
# lon                                                       0
# Tot_comp_Student                                         48
# Enrolment                                               312
# _tot_func_computers                                       1
# type_connectivity                                       NaN
# uuid                   9d6d356d-1a45-4920-923f-91eae6baf5d5
# country_code                                             ZW
# owner                                                UNICEF
# is_private                                             True
# provider                                            unknown
# provider_is_private                                    True
# Name: 8756, dtype: object
# WARNING:root:1 validation error for School
# __root__
#   invalid lat,lon of 0,0 for name: AMR SISTERS ROMAN CATHOLIC, uuid: 9d6d356d-1a45-4920-923f-91eae6baf5d5 (type=value_error)
# WARNING:root:Schoolnumber                                          12977
# name                              KUSILE GOVERNMENT PRIMARY
# SchoolLevel                                         Primary
# admin2                                   Matabeleland North
# lat                                                       0
# lon                                                       0
# Tot_comp_Student                                         48
# Enrolment                                               221
# _tot_func_computers                                      70
# type_connectivity                                      ADSL
# uuid                   0f3a1e1f-a62e-471c-bc59-f3ff67a41330
# country_code                                             ZW
# owner                                                UNICEF
# is_private                                             True
# provider                                            unknown
# provider_is_private                                    True
# Name: 8757, dtype: object
# WARNING:root:1 validation error for School
# __root__
#   invalid lat,lon of 0,0 for name: KUSILE GOVERNMENT PRIMARY, uuid: 0f3a1e1f-a62e-471c-bc59-f3ff67a41330 (type=value_error)
# 0       country_code='ZW' admin0=None admin1=None admi...
# 1       country_code='ZW' admin0=None admin1=None admi...
# 2       country_code='ZW' admin0=None admin1=None admi...
# 3       country_code='ZW' admin0=None admin1=None admi...
# 4       country_code='ZW' admin0=None admin1=None admi...
#                               ...
# 8269    country_code='ZW' admin0=None admin1=None admi...
# 8523                                                False
# 8739    country_code='ZW' admin0=None admin1=None admi...
# 8756                                                False
# 8757                                                False
# Length: 7922, dtype: object

# %%
# filter out the False values from the series_to_school apply
schools = res[res.values != False]
schools
# Out:
# 0       country_code='ZW' admin0=None admin1=None admi...
# 1       country_code='ZW' admin0=None admin1=None admi...
# 2       country_code='ZW' admin0=None admin1=None admi...
# 3       country_code='ZW' admin0=None admin1=None admi...
# 4       country_code='ZW' admin0=None admin1=None admi...
#                               ...
# 8266    country_code='ZW' admin0=None admin1=None admi...
# 8267    country_code='ZW' admin0=None admin1=None admi...
# 8268    country_code='ZW' admin0=None admin1=None admi...
# 8269    country_code='ZW' admin0=None admin1=None admi...
# 8739    country_code='ZW' admin0=None admin1=None admi...
# Length: 7919, dtype: object

# %%
# values are validated Pydantic models representing a school
schools.values[0]
# Out:
# School(country_code='ZW', admin0=None, admin1=None, admin2='Harare', admin3=None, admin4=None, admin_code=None, admin_id=None, name='ADMIRAL TAIT', address=None, address2=None, phone_number=None, person_contact=None, email=None, postal_code=None, lon=31.08971, lat=-17.82644, altitude=None, gps_confidence=None, date=None, num_students=None, num_teachers=None, connectivity=None, type_connectivity=<Connectivity.dsl: 'DSL'>, speed_connectivity=None, latency_connectivity=None, availability_connectivity=None, num_computers=None, type_school=None, educ_level=None, environment=None, num_classrooms=None, num_sections=None, water=None, electricity=None, num_latrines=None, provider='unknown', description=None, last_update=None, tower_dist=None, tower_type_service=None, tower_type=None, tower_code=None, tower_latitude=None, tower_longitude=None, owner='UNICEF', is_private=True, provider_is_private=True, uuid=UUID('2566e8ff-59dc-4b10-8669-31e890102528'))
