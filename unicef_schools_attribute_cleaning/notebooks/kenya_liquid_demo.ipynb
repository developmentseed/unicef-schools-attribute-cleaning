# %%
import logging
import pandas as pd
from iso3166 import countries

from csv import QUOTE_NONNUMERIC
from unicef_schools_attribute_cleaning.pandas.dataframe_cleaner import dataframe_cleaner

# make INFO logs visible
logging.basicConfig(level=logging.INFO)

# %%
src_df = pd.read_csv('../../data/UNICE_schools_raw_2020_Jun/liquid_schools.csv', low_memory=False)
src_df
# Out:
#                     Name of School       Province  District    County  \
# 0                 SOUTHEND ACADEMY        WESTERN   BUNGOMA   BUNGOMA
# 1                JOY SHIRU PRI SCH        NAIROBI   NAIROBI   NAIROBI
# 2              ST EDWARDS HIGH SCH        NAIROBI   STAREHE       NaN
# 3            NAIVASHA PRI BOARDING    RIFT VALLEY    NAKURU    NAKURU
# 4                 MLOLONGO PRI SCH        EASTERN  MACHAKOS  MACHAKOS
# ...                            ...            ...       ...       ...
# 32480      DAVA INTEGRATED PRI SCH  NORTH EASTERN   MANDERA   MANDERA
# 32481            DAVA SPECIAL UNIT  NORTH EASTERN   MANDERA   MANDERA
# 32482  BORDER VIEW ACADEMY PRI SCH  NORTH EASTERN   MANDERA   MANDERA
# 32483             BURUBURU PRI SCH  NORTH EASTERN   MANDERA   MANDERA
# 32484              B.P.ONE PRI SCH  NORTH EASTERN   MANDERA   MANDERA
#
#        Latitude  Longitude  Distance(Km)
# 0      0.562360  34.561880      0.000038
# 1     -1.265244  36.750676      0.000144
# 2     -1.272549  36.822084      0.000158
# 3     -0.704300  36.435070      0.000195
# 4     -1.388401  36.935328      0.000218
# ...         ...        ...           ...
# 32480  3.953030  41.860900    401.815377
# 32481  3.953030  41.860900    401.815377
# 32482  3.942400  41.867270    402.275520
# 32483  3.947800  41.868850    402.566618
# 32484  3.969920  41.886510    404.986109
#
# [32485 rows x 7 columns]

# %%
country = countries.get('KE')
df = dataframe_cleaner(
    dataframe=src_df,
    country=country,
    is_private=True,
    provider='LIQUID',
    provider_is_private=True
)
df
# Out:
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:copying dataframe...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:standardizing column names...
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:uuid column not found, generating uuid4
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:renaming columns: {'District': 'admin3',
#  'Latitude': 'lat',
#  'Longitude': 'lon',
#  'Name of School': 'name',
#  'Province': 'admin2'}
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:adding 38 columns from schema: ['admin0',
#  'admin1',
#  'admin4',
#  'admin_code',
#  'admin_id',
#  'address',
#  'address2',
#  'phone_number',
#  'person_contact',
#  'email',
#  'postal_code',
#  'altitude',
#  'gps_confidence',
#  'date',
#  'num_students',
#  'num_teachers',
#  'connectivity',
#  'type_connectivity',
#  'speed_connectivity',
#  'latency_connectivity',
#  'availability_connectivity',
#  'num_computers',
#  'type_school',
#  'educ_level',
#  'environment',
#  'num_classrooms',
#  'num_sections',
#  'water',
#  'electricity',
#  'num_latrines',
#  'description',
#  'last_update',
#  'tower_dist',
#  'tower_type_service',
#  'tower_type',
#  'tower_code',
#  'tower_latitude',
#  'tower_longitude']
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:removing columns: ['County', 'Distance(Km)'] (not in School schema)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filtering rows missing lat,lon...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filtering rows missing lat,lon -> before: 32485 rows, after filter: 32485 rows
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filter & validate each school row to the schema...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filter & validate each school row to the schema -> before: 32485 rows, after filter: 32485 rows
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:lookup GADM areas by lat,lon...
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:cache hit for: https://biogeo.ucdavis.edu/data/gadm3.6/gpkg/gadm36_KEN_gpkg.zip
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:converting geopackage file...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:processing each lat,lon into GADM area...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=ST. AUGUSTINE  PREP PRY  SCH, lat,lng=-4.029381,39.661509 https://www.openstreetmap.org/#map=18/-4.029381/39.661509 (uuid=cf584995-c088-467b-a458-e69991849365)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=SEA BREEZE ACADEMY PRI, lat,lng=-4.07791,39.6567 https://www.openstreetmap.org/#map=18/-4.07791/39.6567 (uuid=15c67c29-7bf5-4ab0-9a32-8cc8a3d9f822)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name

# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=BIDII ADVENTIST PRI, lat,lng=3.527922,39.062889 https://www.openstreetmap.org/#map=18/3.527922/39.062889 (uuid=b0f74bf5-4c40-4242-9cfb-faccb06b7e56)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=ST MARY'S PRI, lat,lng=3.529292,39.06248 https://www.openstreetmap.org/#map=18/3.529292/39.06248 (uuid=02dee93d-e5e9-4efe-b819-883900b5c612)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=AL - KHULAFAU RASHIDIN PRI, lat,lng=3.533834,39.061811 https://www.openstreetmap.org/#map=18/3.533834/39.061811 (uuid=b9728bff-dc08-4c3f-b29d-3c2d5c440a0f)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=AL - KHULAFAU RASHIDIN ISLAMIC CENTRE MADRASSA, lat,lng=3.533834,39.061811 https://www.openstreetmap.org/#map=18/3.533834/39.061811 (uuid=94ffa08f-ecb2-4646-ab6e-07ccf9396229)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=EYMOLE PRI SCH, lat,lng=4.04117,40.19926 https://www.openstreetmap.org/#map=18/4.04117/40.19926 (uuid=ff0c587d-075a-40bb-beef-643de9229fef)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=MALKAMARI PRI SCH, lat,lng=4.23949,40.69539 https://www.openstreetmap.org/#map=18/4.23949/40.69539 (uuid=dda41f45-7e2f-44f1-b369-4f2286e4b147)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=RHAMU DIMTU PRI SCH, lat,lng=4.02345,41.06493 https://www.openstreetmap.org/#map=18/4.02345/41.06493 (uuid=f54aaf49-0626-434d-87fb-13308a509d31)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=KIBISH PRI SCH, lat,lng=5.28947,35.82275 https://www.openstreetmap.org/#map=18/5.28947/35.82275 (uuid=924f0684-0785-4967-b8c2-52555f187d8d)
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=KIBISH PRI SCH, lat,lng=5.28947,35.82275 https://www.openstreetmap.org/#map=18/5.28947/35.82275 (uuid=924f0684-0785-4967-b8c2-52555f187d8d)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=KOYASA PRI SCH, lat,lng=4.97195,35.48529 https://www.openstreetmap.org/#map=18/4.97195/35.48529 (uuid=100185b3-0be9-4cc3-8edb-a78a3a989538)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=KHLALIO PRI SCH, lat,lng=3.96773,41.61659 https://www.openstreetmap.org/#map=18/3.96773/41.61659 (uuid=0e0f4402-613a-4e0d-974a-047edbc7ce35)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=BUR ABOR PRI SCH, lat,lng=3.97519,41.70959 https://www.openstreetmap.org/#map=18/3.97519/41.70959 (uuid=715ed078-2046-4f2a-ad3a-c6f4edf76e42)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=FIKOW PRI SCH, lat,lng=3.97622,41.73985 https://www.openstreetmap.org/#map=18/3.97622/41.73985 (uuid=4178d50e-8e1b-4583-b522-5878b60b9495)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:readying pandas data types...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:done
#       country_code admin0    admin1        admin2              admin3 admin4  \
# 0               KE  Kenya   Bungoma       Kanduyi             Khalaba   None
# 1               KE  Kenya   Nairobi     Westlands             Kangemi   None
# 2               KE  Kenya   Nairobi       Starehe               Ngara   None
# 3               KE  Kenya    Nakuru      Naivasha           Viwandani   None
# 4               KE  Kenya  Machakos        Mavoko  Syokimau/Mulolongo   None
# ...            ...    ...       ...           ...                 ...    ...
# 32480           KE  Kenya   Mandera  Mandera East            Township   None
# 32481           KE  Kenya   Mandera  Mandera East            Township   None
# 32482           KE  Kenya   Mandera  Mandera East            Township   None
# 32483           KE  Kenya   Mandera  Mandera East            Township   None
# 32484           KE  Kenya   Mandera  Mandera East            Township   None
#
#           admin_code                     admin_id  \
# 0        KEN.3.3.4_1    3.6,KEN,GID_3=KEN.3.3.4_1
# 1      KEN.30.17.1_1  3.6,KEN,GID_3=KEN.30.17.1_1
# 2      KEN.30.16.4_1  3.6,KEN,GID_3=KEN.30.16.4_1
# 3       KEN.31.6.8_1   3.6,KEN,GID_3=KEN.31.6.8_1
# 4       KEN.22.6.4_1   3.6,KEN,GID_3=KEN.22.6.4_1
# ...              ...                          ...
# 32480   KEN.24.3.6_1   3.6,KEN,GID_3=KEN.24.3.6_1
# 32481   KEN.24.3.6_1   3.6,KEN,GID_3=KEN.24.3.6_1
# 32482   KEN.24.3.6_1   3.6,KEN,GID_3=KEN.24.3.6_1
# 32483   KEN.24.3.6_1   3.6,KEN,GID_3=KEN.24.3.6_1
# 32484   KEN.24.3.6_1   3.6,KEN,GID_3=KEN.24.3.6_1
#
#                               name address  ... description last_update  \
# 0                 SOUTHEND ACADEMY    None  ...        None        None
# 1                JOY SHIRU PRI SCH    None  ...        None        None
# 2              ST EDWARDS HIGH SCH    None  ...        None        None
# 3            NAIVASHA PRI BOARDING    None  ...        None        None
# 4                 MLOLONGO PRI SCH    None  ...        None        None
# ...                            ...     ...  ...         ...         ...
# 32480      DAVA INTEGRATED PRI SCH    None  ...        None        None
# 32481            DAVA SPECIAL UNIT    None  ...        None        None
# 32482  BORDER VIEW ACADEMY PRI SCH    None  ...        None        None
# 32483             BURUBURU PRI SCH    None  ...        None        None
# 32484              B.P.ONE PRI SCH    None  ...        None        None
#
#       tower_dist tower_type_service tower_type  tower_code  tower_latitude  \
# 0           None               None       None        None            None
# 1           None               None       None        None            None
# 2           None               None       None        None            None
# 3           None               None       None        None            None
# 4           None               None       None        None            None
# ...          ...                ...        ...         ...             ...
# 32480       None               None       None        None            None
# 32481       None               None       None        None            None
# 32482       None               None       None        None            None
# 32483       None               None       None        None            None
# 32484       None               None       None        None            None
#
#       tower_longitude is_private                                  uuid
# 0                None       True  7a7fe5d9-107c-43c2-9f27-2f0bb4c2c61d
# 1                None       True  d493c470-d941-4d92-896a-eb204d93a738
# 2                None       True  d4cf87ae-bbbd-4c4b-8acf-c7a13392adc2
# 3                None       True  5325fc41-1639-4eb0-8e03-9b3480b1b8fa
# 4                None       True  bcd6f786-cb21-40f8-8040-cca803583bf2
# ...               ...        ...                                   ...
# 32480            None       True  8eff753a-2745-4dd7-b5ff-e594fd280ae4
# 32481            None       True  5fbdd742-5a8a-458b-a1c1-58269077ff4c
# 32482            None       True  21ab1c4a-c268-4355-a054-79d3fb39f270
# 32483            None       True  3ccb1991-017a-47a2-9af0-ec75a8525a9e
# 32484            None       True  86282189-93c8-4e8e-9969-d22f8df248af
#
# [32485 rows x 48 columns]

# %%
df.to_csv('kenya_liquid_cleaned.csv', quoting=QUOTE_NONNUMERIC, index=False)

# %%
# open in LibreOffice, Excel, other
# !open kenya_liquid_cleaned.csv
