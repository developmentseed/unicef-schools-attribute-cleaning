# %%
import logging
import pandas as pd
from iso3166 import countries

from csv import QUOTE_NONNUMERIC
from unicef_schools_attribute_cleaning.pandas.standardize_column_names import standardize_column_names
from unicef_schools_attribute_cleaning.pandas.dataframe_cleaner import dataframe_cleaner

# make INFO logs visible
logging.basicConfig(level=logging.INFO)

# %%
src_df = pd.read_csv('../../data/UNICE_schools_raw_2020_Jun/HN-UNICEF-0-government-0.csv', low_memory=False)
# src_df = pd.read_csv('../../data/unicef_fixed/honduras_original_uuid.csv', low_memory=False)

src_df
# Out:
#           admin2    admin3  school_id                          name  \
# 0      Atlántida  La Ceiba   10100001  ESCUELA GUADALUPE DE QUEZADA
# 1      Atlántida  La Ceiba   10100002        JOSE CECILIO DEL VALLE
# 2      Atlántida  La Ceiba   10100004             AUGUSTO C  COELLO
# 3      Atlántida  La Ceiba   10100005         JOSE TRINIDAD CABAÑAS
# 4      Atlántida  La Ceiba   10100006           GUSTAVO A CASTAÑEDA
# ...          ...       ...        ...                           ...
# 17587        NaN       NaN   80100113                           NaN
# 17588        NaN       NaN   80100203                           NaN
# 17589        NaN       NaN  150300138                           NaN
# 17590        NaN       NaN  150300038                           NaN
# 17591        NaN       NaN  150100179                           NaN
#
#       educ_level environment                               address       lon  \
# 0         Básica      Urbano  BARRIO EL CENTRO, AVENIDA SAN ISIDRO -91.48873
# 1         Básica      Urbano                           BELLA VISTA -86.78323
# 2         Básica      Urbano                              B INGLES -86.79567
# 3         Básica      Urbano                             LA MERCED -86.78438
# 4         Básica      Urbano                               B MEJIA -86.79670
# ...          ...         ...                                   ...       ...
# 17587        NaN         NaN                                   NaN       NaN
# 17588        NaN         NaN                                   NaN       NaN
# 17589        NaN         NaN                                   NaN       NaN
# 17590        NaN         NaN                                   NaN       NaN
# 17591        NaN         NaN                                   NaN       NaN
#
#             lat            admin4  speed_connectivity
# 0       0.00001               NaN                 NaN
# 1      15.77059               NaN                 NaN
# 2      15.78602          LA CEIBA                 0.0
# 3      15.77758          LA CEIBA                 0.0
# 4      15.77411          LA CEIBA                 0.0
# ...         ...               ...                 ...
# 17587       NaN  DISTRITO CENTRAL                 4.0
# 17588       NaN  DISTRITO CENTRAL                 4.0
# 17589       NaN         CATACAMAS                 4.0
# 17590       NaN       LAS MESETAS                 4.0
# 17591       NaN         JUTICALPA                 4.0
#
# [17592 rows x 11 columns]

# %%
country = countries.get('HN')
df = dataframe_cleaner(dataframe=src_df.head(1000), country=country)
df
# Out:
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:copying dataframe...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:standardizing column names...
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:uuid column not found, generating uuid4
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:adding 33 columns from schema: ['admin0',
#  'admin1',
#  'admin_code',
#  'admin_id',
#  'address2',
#  'phone_number',
#  'person_contact',
#  'email',
#  'postal_code',
#  'altitude',
#  'gps_confidence',
#  'date',
#  'num_students',
#  'num_teachers',
#  'connectivity',
#  'type_connectivity',
#  'latency_connectivity',
#  'availability_connectivity',
#  'num_computers',
#  'type_school',
#  'num_classrooms',
#  'num_sections',
#  'water',
#  'electricity',
#  'num_latrines',
#  'description',
#  'last_update',
#  'tower_dist',
#  'tower_type_service',
#  'tower_type',
#  'tower_code',
#  'tower_latitude',
#  'tower_longitude']
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:removing columns: ['school_id'] (not in School schema)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filtering rows missing lat,lon...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:validating each school row to the schema...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:lookup GADM areas by lat,lon...
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:cache hit for: https://biogeo.ucdavis.edu/data/gadm3.6/gpkg/gadm36_HND_gpkg.zip
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:converting geopackage file...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:processing each lat,lon...
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=ESCUELA GUADALUPE DE QUEZADA, lat,lng=1e-05,-91.48873 https://www.openstreetmap.org/#map=18/1e-05/-91.48873 (uuid=e46b6369-38b7-4410-9256-93d5fb49699e)
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=JUAN MANUEL GALVEZ, lat,lng=1e-05,-91.48873 https://www.openstreetmap.org/#map=18/1e-05/-91.48873 (uuid=d4def87c-7e72-4555-a60c-a6797a867f60)
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=MISIONERO JULIO DIAZ, lat,lng=1e-05,-91.48873 https://www.openstreetmap.org/#map=18/1e-05/-91.48873 (uuid=53d5f88e-c9c4-4326-90f0-385702d9bfdb)
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=EVANGELICO EMANUEL No 3, lat,lng=1e-05,-91.48873 https://www.openstreetmap.org/#map=18/1e-05/-91.48873 (uuid=ee3cd74c-8ef9-4b56-9b93-08d6c2951e85)
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=FROYLAN TURCIOS, lat,lng=1e-05,-91.48873 https://www.openstreetmap.org/#map=18/1e-05/-91.48873 (uuid=0759668b-30ae-421f-bcaf-09f70fd6e531)
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=LEMPIRA, lat,lng=1e-05,-91.48873 https://www.openstreetmap.org/#map=18/1e-05/-91.48873 (uuid=34a6e9ae-f1ad-4dab-8e6d-2d1d7e6cc346)
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=RENOVACION, lat,lng=1e-05,-91.48873 https://www.openstreetmap.org/#map=18/1e-05/-91.48873 (uuid=7bb9db7a-509d-44c8-9f3b-6eda29824d61)
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=CARLOS MATUTE, lat,lng=1e-05,-91.48873 https://www.openstreetmap.org/#map=18/1e-05/-91.48873 (uuid=09efdcbe-1698-4797-9d11-6a06089cf495)
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=LORENZO MENDOZA, lat,lng=1e-05,-91.48873 https://www.openstreetmap.org/#map=18/1e-05/-91.48873 (uuid
# 4             HN  Honduras  Atlántida  La Ceiba  La Ceiba  LA CEIBA
# ..           ...       ...        ...       ...       ...       ...
# 995           HN  Honduras      Colón     Limón     Limón       nan
# 996           HN      <NA>       <NA>      <NA>     Limón       nan
# 997           HN      <NA>       <NA>      <NA>     Limón       nan
# 998           HN  Honduras      Colón     Limón     Limón       nan
# 999           HN  Honduras      Colón     Limón     Limón       nan
#
#     admin_code                 admin_id                          name  \
# 0         <NA>        3.6,HND,GID_2=nan  ESCUELA GUADALUPE DE QUEZADA
# 1    HND.1.5_1  3.6,HND,GID_2=HND.1.5_1        JOSE CECILIO DEL VALLE
# 2    HND.1.5_1  3.6,HND,GID_2=HND.1.5_1             AUGUSTO C  COELLO
# 3    HND.1.5_1  3.6,HND,GID_2=HND.1.5_1         JOSE TRINIDAD CABAÑAS
# 4    HND.1.5_1  3.6,HND,GID_2=HND.1.5_1           GUSTAVO A CASTAÑEDA
# ..         ...                      ...                           ...
# 995  HND.3.4_1  3.6,HND,GID_2=HND.3.4_1               19 DE DICIEMBRE
# 996       <NA>        3.6,HND,GID_2=nan                 LUZ DEL SABER
# 997       <NA>        3.6,HND,GID_2=nan             FRANCISCO MORAZAN
# 998  HND.3.4_1  3.6,HND,GID_2=HND.3.4_1    SILVERIO HERNANDEZ TINGLOS
# 999  HND.3.4_1  3.6,HND,GID_2=HND.3.4_1       PABLO PORTILLO FIGUEROA
#
#                                            address  ... description  \
# 0             BARRIO EL CENTRO, AVENIDA SAN ISIDRO  ...        None
# 1                                      BELLA VISTA  ...        None
# 2                                         B INGLES  ...        None
# 3                                        LA MERCED  ...        None
# 4                                          B MEJIA  ...        None
# ..                                             ...  ...         ...
# 995                                ALDEA LIMONCITO  ...        None
# 996  EL GUANO ADELANTE DE LA COMUNIDAD DEL PARAISO  ...        None
# 997                                          LIMON  ...        None
# 998                      FLORES DE ORIENTE TINGLAS  ...        None
# 999                                         PLANES  ...        None
#
#     last_update tower_dist tower_type_service tower_type  tower_code  \
# 0          None       None               None       None        None
# 1          None       None               None       None        None
# 2          None       None               None       None        None
# 3          None       None               None       None        None
# 4          None       None               None       None        None
# ..          ...        ...                ...        ...         ...
# 995        None       None               None       None        None
# 996        None       None               None       None        None
# 997        None       None               None       None        None
# 998        None       None               None       None        None
# 999        None       None               None       None        None
#
#      tower_latitude tower_longitude is_private  \
# 0              None            None       True
# 1              None            None       True
# 2              None            None       True
# 3              None            None       True
# 4              None            None       True
# ..              ...             ...        ...
# 995            None            None       True
# 996            None            None       True
# 997            None            None       True
# 998            None            None       True
# 999            None            None       True
#
#                                      uuid
# 0    e46b6369-38b7-4410-9256-93d5fb49699e
# 1    c6eac3c4-db4d-445e-8196-24b3d464ae6a
# 2    b710b46b-0733-48f5-a62e-a4e76edff668
# 3    1ea58e69-28c2-4a80-9f6e-89817cc05565
# 4    636634df-b643-4480-9379-14be10ee8080
# ..                                    ...
# 995  485b9422-57ee-485c-85ef-651939fb13dd
# 996  7dd6208a-ed92-4f25-8ed0-2f26fed2b212
# 997  81d2a382-a517-4d65-8122-5dbea39e6302
# 998  c998cc1a-6d75-47f0-9fef-13236acc2a42
# 999  84c06f3d-dd54-4382-a742-efbf09948dae
#
# [1000 rows x 48 columns]

# %%
df.to_csv('honduras_cleaned.csv', quoting=QUOTE_NONNUMERIC, index=False)

# %%
# open in LibreOffice, Excel, other
# !open honduras_cleaned.csv
