# %%
import logging
import pandas as pd
from iso3166 import countries

from csv import QUOTE_NONNUMERIC
from unicef_schools_attribute_cleaning.pandas.dataframe_cleaner import dataframe_cleaner

# make INFO logs visible
logging.basicConfig(level=logging.INFO)

# %%
src_df = pd.read_csv('../../data/UNICE_schools_raw_2020_Jun/usaid_schools.csv', low_memory=False)
src_df
# Out:
#         Region county_id         county  county_code subCounty_id  \
# 0      Eldoret  ep8yqMKT        Baringo            1     dKpabrnG
# 1      Eldoret  ep8yqMKT        Baringo            1     dKpabrnG
# 2      Eldoret  ep8yqMKT        Baringo            1     dKpabrnG
# 3      Eldoret  ep8yqMKT        Baringo            1     dKpabrnG
# 4      Eldoret  ep8yqMKT        Baringo            1     dKpabrnG
# ...        ...       ...            ...          ...          ...
# 26115  Nairobi  YFZjN4qd      Nyandarua           35     cSaQj4aa
# 26116  Nairobi  YFZjN4qd      Nyandarua           35     cSaQj4aa
# 26117  Nairobi  YFZjN4qd      Nyandarua           35     cSaQj4aa
# 26118  Nairobi  YFZjN4qd      Nyandarua           35     cSaQj4aa
# 26119  Nairobi  YFZjN4qd  Nyandarua SNE           35     xQaGMtX9
#
#              subCounty  subsCounty_code   zone_id          zone  zone_code  \
# 0      Baringo Central                1  SyYZ2NEn      Chapchap          1
# 1      Baringo Central                1  SyYZ2NEn      Chapchap          1
# 2      Baringo Central                1  SyYZ2NEn      Chapchap          1
# 3      Baringo Central                1  SyYZ2NEn      Chapchap          1
# 4      Baringo Central                1  SyYZ2NEn      Chapchap          1
# ...                ...              ...       ...           ...        ...
# 26115   Nyandarua West                7  UEnbPUHp  Ol Joro Orok          2
# 26116   Nyandarua West                7  UEnbPUHp  Ol Joro Orok          2
# 26117   Nyandarua West                7  UEnbPUHp  Ol Joro Orok          2
# 26118   Nyandarua West                7  UEnbPUHp  Ol Joro Orok          2
# 26119  Nyandarua South                6  9AAtWvX4      Engineer          1
#
#       school_id                  school  verified_latitude  \
# 0           NaN               Chebunyor                NaN
# 1      9CWwjhDS              Kabarbarma          -1.259261
# 2      R2wzR2g4               Kabochony           0.440002
# 3      nemmFtXC                 Kapkiai           0.426389
# 4           NaN               Kapkoimet                NaN
# ...         ...                     ...                ...
# 26115  VXhwMAjT               Riverside           0.011700
# 26116  Pw4HvM8t                   Uhuru          -0.143029
# 26117  paM6wjfP                 Uiguano          -0.173542
# 26118  3xxcCXh6                    Weru          -0.139374
# 26119  zrqwvsSx  Nyandarua Sch For Deaf                NaN
#
#        verified_longitude  school_code  tusome_code REGULAR / SNE  \
# 0                     NaN         13.0    1101013.0       REGULAR
# 1               36.803921          1.0    1101001.0       REGULAR
# 2               35.800895          2.0    1101002.0       REGULAR
# 3               35.805504          3.0    1101003.0       REGULAR
# 4                     NaN         14.0    1101014.0       REGULAR
# ...                   ...          ...          ...           ...
# 26115           36.357299         24.0   35702024.0       REGULAR
# 26116           36.311293         25.0   35702025.0       REGULAR
# 26117           36.385639         26.0   35702026.0       REGULAR
# 26118           36.380180         27.0   35702027.0       REGULAR
# 26119                 NaN         17.0   35601017.0           SNE
#
#       PUBLIC / APBET / HI / VI / HI&VI 2019_Active / Inactive status
# 0                               PUBLIC                        Active
# 1                               PUBLIC                        Active
# 2                               PUBLIC                        Active
# 3                               PUBLIC                        Active
# 4                               PUBLIC                        Active
# ...                                ...                           ...
# 26115                           PUBLIC                        Active
# 26116                           PUBLIC                        Active
# 26117                           PUBLIC                        Active
# 26118                           PUBLIC                        Active
# 26119                               HI                        Active
#
# [26120 rows x 19 columns]

# %%
src_df.columns
# Out:
# Index(['Region', 'county_id', 'county', 'county_code', 'subCounty_id',
#        'subCounty', 'subsCounty_code', 'zone_id', 'zone', 'zone_code',
#        'school_id', 'school', 'verified_latitude', 'verified_longitude',
#        'school_code', 'tusome_code', 'REGULAR / SNE',
#        'PUBLIC / APBET / HI / VI / HI&VI', '2019_Active / Inactive status'],
#       dtype='object')

# %%
# Problem: there are columns 'REGULAR / SNE' and 'PUBLIC / APBET / HI / VI / HI&VI', which look like possibly SchoolType field(s), but 
# it's hard to say without knowledge of the data source. The dataframe_cleaner will just skip those columns because they do not match the schema.
src_df['PUBLIC / APBET / HI / VI / HI&VI'].unique()
# Out:
# array(['PUBLIC', 'HI', 'HI&VI', 'VI', 'MH', 'APBET', 'MD'], dtype=object)

# %%
country = countries.get('KE')
df = dataframe_cleaner(
    dataframe=src_df,
    country=country,
    is_private=True,
    provider='USAID',
    provider_is_private=True
)
df
# Out:
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:copying dataframe...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:standardizing column names...
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:uuid column not found, generating uuid4
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:renaming columns: {'county': 'admin2',
#  'school': 'name',
#  'verified_latitude': 'lat',
#  'verified_longitude': 'lon'}
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:adding 39 columns from schema: ['admin0',
#  'admin1',
#  'admin3',
#  'admin4',
#  'admin_code',
#  'admin_id',
#  'address',
#  'address2',
#  'phone_number',
#  'person_contact',
#  'email',
#  'postal_code',
#  'altitude',
#  'gps_confidence',
#  'date',
#  'num_students',
#  'num_teachers',
#  'connectivity',
#  'type_connectivity',
#  'speed_connectivity',
#  'latency_connectivity',
#  'availability_connectivity',
#  'num_computers',
#  'type_school',
#  'educ_level',
#  'environment',
#  'num_classrooms',
#  'num_sections',
#  'water',
#  'electricity',
#  'num_latrines',
#  'description',
#  'last_update',
#  'tower_dist',
#  'tower_type_service',
#  'tower_type',
#  'tower_code',
#  'tower_latitude',
#  'tower_longitude']
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:removing columns: ['Region',
#  'county_id',
#  'county_code',
#  'subCounty_id',
#  'subCounty',
#  'subsCounty_code',
#  'zone_id',
#  'zone',
#  'zone_code',
#  'school_id',
#  'school_code',
#  'tusome_code',
#  'REGULAR / SNE',
#  'PUBLIC / APBET / HI / VI / HI&VI',
#  '2019_Active / Inactive status'] (not in School schema)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filtering rows missing lat,lon...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filtering rows missing lat,lon -> before: 26120 rows, after filter: 20381 rows
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filter & validate each school row to the schema...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filter & validate each school row to the schema -> before: 20381 rows, after filter: 20381 rows
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:lookup GADM areas by lat,lon...
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:cache hit for: https://biogeo.ucdavis.edu/data/gadm3.6/gpkg/gadm36_KEN_gpkg.zip
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:converting geopackage file...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:processing each lat,lon into GADM area...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=Kebee, lat,lng=-2.356542985,61.43301773 https://www.openstreetmap.org/#map=18/-2.356542985/61.43301773 (uuid=8008dda9-28d0-42d0-8591-d9c49bc5e8c0)
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=Kebee, lat,lng=-2.356542985,61.43301773 https://www.openstreetmap.org/#map=18/-2.356542985/61.43301773 (uuid=8008dda9-28d0-42d0-8591-d9c49bc5e8c0)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=Eymole, lat,lng=4.038103104,40.20059204 https://www.openstreetmap.org/#map=18/4.038103104/40.20059204 (uuid=139fb2ad-a518-4907-bde4-d43e61f682d6)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:readying pandas data types...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:done
#       country_code admin0     admin1           admin2               admin3  \
# 1               KE  Kenya    Nairobi        Westlands  Parklands/Highridge
# 2               KE  Kenya    Baringo  Baringo Central      Ewalel/Chapchap
# 3               KE  Kenya    Baringo  Baringo Central      Ewalel/Chapchap
# 5               KE  Kenya    Baringo  Baringo Central      Ewalel/Chapchap
# 6               KE  Kenya    Baringo  Baringo Central            Kapropita
# ...            ...    ...        ...              ...                  ...
# 26114           KE  Kenya  Nyandarua         Ol Jorok            Charagita
# 26115           KE  Kenya  Nyandarua         Ol Jorok               Gatimu
# 26116           KE  Kenya  Nyandarua         Ol Jorok            Charagita
# 26117           KE  Kenya  Nyandarua         Ol Kalou                Rurii
# 26118           KE  Kenya  Nyandarua         Ol Jorok                 Weru
#
#       admin4     admin_code                     admin_id          name  \
# 1       None  KEN.30.17.5_1  3.6,KEN,GID_3=KEN.30.17.5_1    Kabarbarma
# 2       None    KEN.1.2.1_1    3.6,KEN,GID_3=KEN.1.2.1_1     Kabochony
# 3       None    KEN.1.2.1_1    3.6,KEN,GID_3=KEN.1.2.1_1       Kapkiai
# 5       None    KEN.1.2.1_1    3.6,KEN,GID_3=KEN.1.2.1_1      Kapkomoi
# 6       None    KEN.1.2.3_1    3.6,KEN,GID_3=KEN.1.2.3_1     Kapngelel
# ...      ...            ...                          ...           ...
# 26114   None   KEN.35.4.1_1   3.6,KEN,GID_3=KEN.35.4.1_1  Ol Joro Orok
# 26115   None   KEN.35.4.3_1   3.6,KEN,GID_3=KEN.35.4.3_1     Riverside
# 26116   None   KEN.35.4.1_1   3.6,KEN,GID_3=KEN.35.4.1_1         Uhuru
# 26117   None   KEN.35.5.5_1   3.6,KEN,GID_3=KEN.35.5.5_1       Uiguano
# 26118   None   KEN.35.4.4_1   3.6,KEN,GID_3=KEN.35.4.4_1          Weru
#
#       address  ... description last_update tower_dist tower_type_service  \
# 1        None  ...        None        None       None               None
# 2        None  ...        None        None       None               None
# 3        None  ...        None        None       None               None
# 5        None  ...        None        None       None               None
# 6        None  ...        None        None       None               None
# ...       ...  ...         ...         ...        ...                ...
# 26114    None  ...        None        None       None               None
# 26115    None  ...        None        None       None               None
# 26116    None  ...        None        None       None               None
# 26117    None  ...        None        None       None               None
# 26118    None  ...        None        None       None               None
#
#       tower_type  tower_code  tower_latitude tower_longitude is_private  \
# 1           None        None            None            None       True
# 2           None        None            None            None       True
# 3           None        None            None            None       True
# 5           None        None            None            None       True
# 6           None        None            None            None       True
# ...          ...         ...             ...             ...        ...
# 26114       None        None            None            None       True
# 26115       None        None            None            None       True
# 26116       None        None            None            None       True
# 26117       None        None            None            None       True
# 26118       None        None            None            None       True
#
#                                        uuid
# 1      613e2b25-d8e5-478e-89aa-df3433371550
# 2      5756e7a6-dc9d-4cee-9e4e-7a9d12594cd9
# 3      d87011b7-835c-4326-9bb5-538c91459b06
# 5      16c10814-1088-4660-abfa-2e67e0d5f1f3
# 6      32b847bc-3027-4c38-a4c6-e7331e32763b
# ...                                     ...
# 26114  eea152ba-b8ec-4c3d-832a-4b141cd259e7
# 26115  d7ec7f8c-5498-472f-a79b-064916dfae29
# 26116  6d7aeed2-b709-4339-9fac-7a465a1eaaa4
# 26117  dd7e93a7-5ca3-4ad6-a773-3043b7373f8d
# 26118  49f916a0-15a5-4e1a-a45b-ae7cc869f82a
#
# [20381 rows x 48 columns]

# %%
df.to_csv('kenya_usaid_cleaned.csv', quoting=QUOTE_NONNUMERIC, index=False)

# %%
# open in LibreOffice, Excel, other
# !open kenya_usaid_cleaned.csv
