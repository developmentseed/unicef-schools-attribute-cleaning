# %%
import logging
import pandas as pd
from iso3166 import countries

from csv import QUOTE_NONNUMERIC
from unicef_schools_attribute_cleaning.pandas.dataframe_cleaner import dataframe_cleaner

# make INFO logs visible
logging.basicConfig(level=logging.INFO)

# %%
src_df = pd.read_csv('../../data/UNICE_schools_raw_2020_Jun/moe_schools.csv', low_memory=False)
src_df
# Out:
#                                Name of School Level of Education  \
# 0                     TAMBAYA PRIMARY  SCHOOL     PRIMARY SCHOOL
# 1      TAMBAYA PRIMARY SCHOOL -  SPECIAL UNIT     PRIMARY SCHOOL
# 2                    SHINING STAR ACADEMY PRI     PRIMARY SCHOOL
# 3                     GAIKUNDO PRIMARY SCHOOL     PRIMARY SCHOOL
# 4                                WANJITHI PRI     PRIMARY SCHOOL
# ...                                       ...                ...
# 31224                          SOWENE PRIMARY     PRIMARY SCHOOL
# 31225                 LEISURE ACADEMY PRIMARY     PRIMARY SCHOOL
# 31226                   TAVETA JUNIOR ACADEMY     PRIMARY SCHOOL
# 31227                        LESSESIA PRIMARY     PRIMARY SCHOOL
# 31228                        ALFATTAH PRIMARY     PRIMARY SCHOOL
#
#       Status of School Province      District     Division Location  \
# 0               PUBLIC  CENTRAL         NYERI  MUKURWE-INI  GAKINDU
# 1               PUBLIC  CENTRAL         NYERI  MUKURWE-INI  GAKINDU
# 2              PRIVATE  CENTRAL         NYERI  MUKURWE-INI  GAKINDU
# 3               PUBLIC  CENTRAL         NYERI  MUKURWE-INI  GAKINDU
# 4               PUBLIC  CENTRAL         NYERI  MUKURWE-INI  GAKINDU
# ...                ...      ...           ...          ...      ...
# 31224           PUBLIC    COAST  TAITA TAVETA       TAVETA   BOMANI
# 31225          PRIVATE    COAST  TAITA TAVETA       TAVETA   BOMANI
# 31226          PRIVATE    COAST  TAITA TAVETA       TAVETA   BOMANI
# 31227           PUBLIC    COAST  TAITA TAVETA       TAVETA   BOMANI
# 31228           PUBLIC    COAST  TAITA TAVETA       TAVETA   BOMANI
#
#        Costituency       lat        lon
# 0      MUKURWE-INI -0.525169  37.017411
# 1      MUKURWE-INI -0.525056  37.018209
# 2      MUKURWE-INI -0.521132  37.013351
# 3      MUKURWE-INI -0.539896  37.001090
# 4      MUKURWE-INI -0.550317  37.001616
# ...            ...       ...        ...
# 31224       TAVETA -3.389600  37.671410
# 31225       TAVETA -3.386770  37.668590
# 31226       TAVETA -3.382530  37.676060
# 31227       TAVETA -3.366570  37.664590
# 31228       TAVETA -3.389400  37.673770
#
# [31229 rows x 10 columns]

# %%
country = countries.get('KE')
with open('kenya_moe_columns_report.txt', mode='w', encoding='utf-8') as filehandle:
    df = dataframe_cleaner(
        dataframe=src_df,
        country=country,
        removed_columns_report=filehandle,
        is_private=True,
        provider='MOE',
        provider_is_private=True
    )
df
# Out:
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:copying dataframe...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:standardizing column names...
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:uuid column not found, generating uuid4
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:renaming columns: {'District': 'admin3',
#  'Level of Education': 'educ_level',
#  'Location': 'admin4',
#  'Name of School': 'name',
#  'Province': 'admin2',
#  'Status of School': 'type_school'}
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:adding 37 columns from schema: ['admin0',
#  'admin1',
#  'admin_code',
#  'admin_id',
#  'address',
#  'address2',
#  'phone_number',
#  'person_contact',
#  'email',
#  'postal_code',
#  'altitude',
#  'gps_confidence',
#  'date',
#  'num_students',
#  'num_teachers',
#  'connectivity',
#  'type_connectivity',
#  'speed_connectivity',
#  'latency_connectivity',
#  'availability_connectivity',
#  'num_computers',
#  'environment',
#  'num_classrooms',
#  'num_sections',
#  'water',
#  'electricity',
#  'num_latrines',
#  'description',
#  'last_update',
#  'tower_dist',
#  'tower_type_service',
#  'tower_type',
#  'tower_code',
#  'tower_latitude',
#  'tower_longitude',
#  'is_invalid',
#  'is_invalid_reason']
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:removing columns: ['Division', 'Costituency'] (not in School schema)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:validate each school row to the schema...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:lookup GADM areas by lat,lon...
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:cache hit for: https://biogeo.ucdavis.edu/data/gadm3.6/gpkg/gadm36_KEN_gpkg.zip
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:converting geopackage file...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:processing each lat,lon into GADM area...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=KOYASA PRI SCH, lat,lng=4.97195,35.48529 https://www.openstreetmap.org/#map=18/4.97195/35.48529 (uuid=70f44e49-2808-4dc3-9aee-14f28e5463df)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=KIBISH PRI SCH, lat,lng=5.28947,35.82275 https://www.openstreetmap.org/#map=18/5.28947/35.82275 (uuid=095d9fc9-aa1f-412f-943d-f495c500feeb)
# WARNING:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:school outside of GADM boundaries name=KIBISH PRI SCH, lat,lng=5.28947,35.82275 https://www.openstreetmap.org/#map=18/5.28947/35.82275 (uuid=095d9fc9-aa1f-412f-943d-f495c500feeb)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=KOKURO PRI SCH, lat,lng=4.6727300000000005,35.706790000000005 https://www.openstreetmap.org/#map=18/4.6727300000000005/35.706790000000005 (uuid=eff8cd0b-1d47-4be9-9c3d-a3df91230e9a)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=REMBA PRI SCH, lat,lng=-0.557829,33.927492 https://www.openstreetmap.org/#map=18/-0.557829/33.927492 (uuid=83b20b76-fd15-4eb7-8645-03452b3d40f0)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=RINGITI PRI, lat,lng=-0.454481,33.93084 https://www.openstreetmap.org/#map=18/-0.454481/33.93084 (uuid=62fc73a9-e5ff-4763-a927-4749907cfd53)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=FIKOW PRI SCH, lat,lng=3.9762199999999996,41.73985 https://www.openstreetmap.org/#map=18/3.9762199999999996/41.73985 (uuid=b5aa77a6-cd93-4a12-a9d4-92da2b0fd325)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=BUR ABOR PRI SCH, lat,lng=3.97519,41.709590000000006 https://www.openstreetmap.org/#map=18/3.97519/41.709590000000006 (uuid=8ff9bbf2-9f7a-4738-93d6-097c2265eb5b)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=KHLALIO PRI SCH, lat,lng=3.9677300000000004,41.61659 https://www.openstreetmap.org/#map=18/3.9677300000000004/41.61659 (uuid=5f071532-befe-48b1-9745-8826821dfe60)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=RHAMU DIMTU PRI SCH, lat,lng=4.02345,41.06493 https://www.openstreetmap.org/#map=18/4.02345/41.06493 (uuid=dd3f3ee9-e968-4ebc-ab77-9ccda3fb6ae6)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=MALKAMARI PRI SCH, lat,lng=4.23949,40.69539 https://www.openstreetmap.org/#map=18/4.23949/40.69539 (uuid=56c3b5e8-c3e8-4ae7-bd9d-5d31d6972fda)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=EYMOLE PRI SCH, lat,lng=4.04117,40.199259999999995 https://www.openstreetmap.org/#map=18/4.04117/40.199259999999995 (uuid=52ccddec-a883-40a0-9baf-6948b2be522e)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=SESSI ACADEMY PRI, lat,lng=3.530218,39.043894 https://www.openstreetmap.org/#map=18/3.530218/39.043894 (uuid=052baf08-70f5-4b1c-99b2-affa61f31484)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=FULL GOSPEL PRI, lat,lng=3.5298230000000004,39.049029 https://www.openstreetmap.org/#map=18/3.5298230000000004/39.049029 (uuid=5423ee4a-31e6-4af0-960f-1a29b0de58ec)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=SOMARE PRI, lat,lng=3.5301440000000004,39.032148 https://www.openstreetmap.org/#map=18/3.5301440000000004/39.032148 (uuid=363895e9-6e12-4915-bef4-4ec4d2ff56eb)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=SESSI PRI, lat,lng=3.528344,39.043017 https://www.openstreetmap.org/#map=18/3.528344/39.043017 (uuid=d61c34bf-d2b2-4aee-b092-7b579490f5b6)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=ST MARY'S PRI, lat,lng=3.529292,39.06248 https://www.openstreetmap.org/#map=18/3.529292/39.06248 (uuid=cb8eb1a5-2aac-46ad-91ab-5079cb250aae)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=BILAL ACADEMY PRI, lat,lng=3.531015,39.058771 https://www.openstreetmap.org/#map=18/3.531015/39.058771 (uuid=4f958090-e121-4429-aa75-141907270d30)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=BIDII ADVENTIST PRI, lat,lng=3.5279220000000002,39.062889 https://www.openstreetmap.org/#map=18/3.5279220000000002/39.062889 (uuid=8267a72f-561f-4db7-a8e4-7c4185c4657e)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=AL - KHULAFAU RASHIDIN PRI, lat,lng=3.5338339999999997,39.061811 https://www.openstreetmap.org/#map=18/3.5338339999999997/39.061811 (uuid=b5d80399-83ec-4472-92ad-5a49d581f5ba)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=AL - KHULAFAU RASHIDIN ISLAMIC CENTRE MADRASSA, lat,lng=3.5338339999999997,39.061811 https://www.openstreetmap.org/#map=18/3.5338339999999997/39.061811 (uuid=087e5638-ac33-4663-9ee1-073dd3e97f24)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=CHRIST THE KING WAYE GODHA PRI, lat,lng=3.609589,38.689807 https://www.openstreetmap.org/#map=18/3.609589/38.689807 (uuid=1e3bc4ef-cdc3-4a3f-9662-193c04fc615a)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=SESSI ACADEMY PRI, lat,lng=3.530218,39.043894 https://www.openstreetmap.org/#map=18/3.530218/39.043894 (uuid=0b196c29-961d-4f2d-94d8-89a391726170)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=FULL GOSPEL PRI, lat,lng=3.5298230000000004,39.049029 https://www.openstreetmap.org/#map=18/3.5298230000000004/39.049029 (uuid=80732d46-24a1-4f84-98bb-1a9e1cc2f6d2)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=SOMARE PRI, lat,lng=3.5301440000000004,39.032148 https://www.openstreetmap.org/#map=18/3.5301440000000004/39.032148 (uuid=71e5bd67-d362-4566-a42f-a99efcf75752)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=SESSI PRI, lat,lng=3.528344,39.043017 https://www.openstreetmap.org/#map=18/3.528344/39.043017 (uuid=6d1f51ae-9722-4405-86c6-01660f905fc1)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=ST MARY'S PRI, lat,lng=3.529292,39.06248 https://www.openstreetmap.org/#map=18/3.529292/39.06248 (uuid=efdc8514-782a-4123-8a4e-d89ca8fe0df3)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=BILAL ACADEMY PRI, lat,lng=3.531015,39.058771 https://www.openstreetmap.org/#map=18/3.531015/39.058771 (uuid=a9222e7c-5f30-4e37-8f68-240b834b7196)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=BIDII ADVENTIST PRI, lat,lng=3.5279220000000002,39.062889 https://www.openstreetmap.org/#map=18/3.5279220000000002/39.062889 (uuid=f98bae8b-c32d-4dd2-a501-0d7f49c0eaa5)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=AL - KHULAFAU RASHIDIN PRI, lat,lng=3.5338339999999997,39.061811 https://www.openstreetmap.org/#map=18/3.5338339999999997/39.061811 (uuid=03bc7557-6576-4ab6-8db1-2a63e1b256e6)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=AL - KHULAFAU RASHIDIN ISLAMIC CENTRE MADRASSA, lat,lng=3.5338339999999997,39.061811 https://www.openstreetmap.org/#map=18/3.5338339999999997/39.061811 (uuid=15f3af85-5655-4df8-ab91-a1b82ea689b9)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=CHRIST THE KING WAYE GODHA PRI, lat,lng=3.609589,38.689807 https://www.openstreetmap.org/#map=18/3.609589/38.689807 (uuid=0195c55f-d6a5-41c2-a3b8-763e6c4730ad)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=KIWAYUU PRI SCH, lat,lng=-2.01797,41.26119 https://www.openstreetmap.org/#map=18/-2.01797/41.26119 (uuid=d0b8bb3f-f080-4869-9a16-3170ed87e76d)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=MUHAKA ISLAMIC PRY SCH, lat,lng=-4.343628,39.575768 https://www.openstreetmap.org/#map=18/-4.343628/39.575768 (uuid=0055c911-e412-48a1-b0c6-44ebaf8d7e50)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=MKWIRO PRY, lat,lng=-4.659708999999999,39.394888 https://www.openstreetmap.org/#map=18/-4.659708999999999/39.394888 (uuid=ae3cce51-cb93-44fa-b405-3ce9bf9dae75)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=ST. AUGUSTINE  PREP PRY  SCH, lat,lng=-4.029381,39.661509 https://www.openstreetmap.org/#map=18/-4.029381/39.661509 (uuid=e243c7e0-0b01-42cc-bb0a-027ba966dbf5)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=SEA BREEZE ACADEMY PRI, lat,lng=-4.07791,39.6567 https://www.openstreetmap.org/#map=18/-4.07791/39.6567 (uuid=0aec28ca-0ddf-4411-9c93-b2ce51596471)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=LIKONI SALVATION ARMY SCH FOR THE BLIND PRY, lat,lng=-4.07616,39.65623 https://www.openstreetmap.org/#map=18/-4.07616/39.65623 (uuid=736f47d6-ce72-4172-98c1-cca8b80ecc58)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=PUMA PRI SCH, lat,lng=-4.07446,39.65247 https://www.openstreetmap.org/#map=18/-4.07446/39.65247 (uuid=acf5ca2a-1d7e-4eb9-9dcc-0ac247bf31dd)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=PELELEZA PRI SCH, lat,lng=-4.0756,39.650290000000005 https://www.openstreetmap.org/#map=18/-4.0756/39.650290000000005 (uuid=eddf1f6a-679c-4909-8787-592226c0e631)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=VICTORY JUNIOR ACADEMY PRI, lat,lng=-4.07216,39.64431 https://www.openstreetmap.org/#map=18/-4.07216/39.64431 (uuid=335e21f2-829a-4b4b-a60f-884e89735d2d)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:readying pandas data types...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:done
#       country_code admin0        admin1      admin2            admin3  \
# 0               KE  Kenya         Nyeri  Mukurweini  Mukurwe-Ini West
# 1               KE  Kenya         Nyeri  Mukurweini  Mukurwe-Ini West
# 2               KE  Kenya         Nyeri  Mukurweini  Mukurwe-Ini West
# 3               KE  Kenya         Nyeri  Mukurweini  Mukurwe-Ini West
# 4               KE  Kenya         Nyeri  Mukurweini  Mukurwe-Ini West
# ...            ...    ...           ...         ...               ...
# 31224           KE  Kenya  Taita Taveta      Taveta            Bomani
# 31225           KE  Kenya  Taita Taveta      Taveta            Bomani
# 31226           KE  Kenya  Taita Taveta      Taveta             Mahoo
# 31227           KE  Kenya  Taita Taveta      Taveta             Mahoo
# 31228           KE  Kenya  Taita Taveta      Taveta            Bomani
#
#         admin4    admin_code                    admin_id  \
# 0      GAKINDU  KEN.36.3.3_1  3.6,KEN,GID_3=KEN.36.3.3_1
# 1      GAKINDU  KEN.36.3.3_1  3.6,KEN,GID_3=KEN.36.3.3_1
# 2      GAKINDU  KEN.36.3.3_1  3.6,KEN,GID_3=KEN.36.3.3_1
# 3      GAKINDU  KEN.36.3.3_1  3.6,KEN,GID_3=KEN.36.3.3_1
# 4      GAKINDU  KEN.36.3.3_1  3.6,KEN,GID_3=KEN.36.3.3_1
# ...        ...           ...                         ...
# 31224   BOMANI  KEN.39.2.1_1  3.6,KEN,GID_3=KEN.39.2.1_1
# 31225   BOMANI  KEN.39.2.1_1  3.6,KEN,GID_3=KEN.39.2.1_1
# 31226   BOMANI  KEN.39.2.3_1  3.6,KEN,GID_3=KEN.39.2.3_1
# 31227   BOMANI  KEN.39.2.3_1  3.6,KEN,GID_3=KEN.39.2.3_1
# 31228   BOMANI  KEN.39.2.1_1  3.6,KEN,GID_3=KEN.39.2.1_1
#
#                                          name address  ... tower_dist  \
# 0                     TAMBAYA PRIMARY  SCHOOL    None  ...       None
# 1      TAMBAYA PRIMARY SCHOOL -  SPECIAL UNIT    None  ...       None
# 2                    SHINING STAR ACADEMY PRI    None  ...       None
# 3                     GAIKUNDO PRIMARY SCHOOL    None  ...       None
# 4                                WANJITHI PRI    None  ...       None
# ...                                       ...     ...  ...        ...
# 31224                          SOWENE PRIMARY    None  ...       None
# 31225                 LEISURE ACADEMY PRIMARY    None  ...       None
# 31226                   TAVETA JUNIOR ACADEMY    None  ...       None
# 31227                        LESSESIA PRIMARY    None  ...       None
# 31228                        ALFATTAH PRIMARY    None  ...       None
#
#       tower_type_service tower_type tower_code tower_latitude  \
# 0                   None       None       None           None
# 1                   None       None       None           None
# 2                   None       None       None           None
# 3                   None       None       None           None
# 4                   None       None       None           None
# ...                  ...        ...        ...            ...
# 31224               None       None       None           None
# 31225               None       None       None           None
# 31226               None       None       None           None
# 31227               None       None       None           None
# 31228               None       None       None           None
#
#        tower_longitude  is_private is_invalid is_invalid_reason  \
# 0                 None        True      False              None
# 1                 None        True      False              None
# 2                 None        True      False              None
# 3                 None        True      False              None
# 4                 None        True      False              None
# ...                ...         ...        ...               ...
# 31224             None        True      False              None
# 31225             None        True      False              None
# 31226             None        True      False              None
# 31227             None        True      False              None
# 31228             None        True      False              None
#
#                                        uuid
# 0      83d60e44-99c8-4396-92de-89ae572c7ab7
# 1      814e6271-f45f-419b-a984-9c7d02bc4507
# 2      f9cb359c-028d-4e0c-bcba-9c7c588fd62e
# 3      4bbe9c0c-6f75-4957-b31d-cb7ccd34478e
# 4      9121fa61-d2fb-4ec7-b8df-1326e164b8e9
# ...                                     ...
# 31224  7a978b45-1724-4c79-95c8-44631a4222a0
# 31225  a0f2358e-aee3-4566-8362-143c81c05e02
# 31226  309edd27-0a7a-4a60-965b-61a220a05d0d
# 31227  b65fd86e-617c-4dbe-aed3-87374146f430
# 31228  db721501-b780-4f01-aa74-7e5ab98a71a2
#
# [31229 rows x 50 columns]

# %%
df.to_csv('kenya_moe_cleaned.csv', quoting=QUOTE_NONNUMERIC, index=False)

# %%
# open in LibreOffice, Excel, other
# !open kenya_moe_cleaned.csv
