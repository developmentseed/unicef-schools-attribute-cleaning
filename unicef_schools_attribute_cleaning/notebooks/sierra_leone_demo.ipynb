# %%
import logging
import pandas as pd
from pandas import Series
from iso3166 import countries
from datetime import datetime
from csv import QUOTE_NONNUMERIC
from unicef_schools_attribute_cleaning.pandas.dataframe_cleaner import dataframe_cleaner

# make INFO logs visible
logging.basicConfig(level=logging.INFO)

# %%
src_df = pd.read_csv('../../data/UNICE_schools_raw_2020_Jun/2019_ASC_schools.csv', low_memory=False)
src_df
# Out:
#       duration             enumerator                           new_school  \
# 0         1740  Morison Mohamed Momoh                   School on the list
# 1         4737  Morison Mohamed Momoh  New School with Paper Questionnaire
# 2         2748  Morison Mohamed Momoh                   School on the list
# 3         1730  Morison Mohamed Momoh                   School on the list
# 4         3143  Morison Mohamed Momoh                   School on the list
# ...        ...                    ...                                  ...
# 11183      NaN                    NaN                                  NaN
# 11184      NaN                    NaN                                  NaN
# 11185      NaN                    NaN                                  NaN
# 11186      NaN                    NaN                                  NaN
# 11187      NaN                    NaN                                  NaN
#
#       idregion iddistrict          idcouncil idchiefdom idward idsection  \
# 0      EASTERN   KAILAHUN  KAILAHUN DISTRICT        DEA     17    SEINGA
# 1      EASTERN   KAILAHUN  KAILAHUN DISTRICT        DEA     15   BAIWALA
# 2      EASTERN   KAILAHUN  KAILAHUN DISTRICT        DEA     17    SIENGA
# 3      EASTERN   KAILAHUN  KAILAHUN DISTRICT        DEA     17   BAIWALA
# 4      EASTERN   KAILAHUN  KAILAHUN DISTRICT        DEA     17    SIENGA
# ...        ...        ...                ...        ...    ...       ...
# 11183      NaN        NaN                NaN        NaN    NaN       NaN
# 11184      NaN        NaN                NaN        NaN    NaN       NaN
# 11185      NaN        NaN                NaN        NaN    NaN       NaN
# 11186      NaN        NaN                NaN        NaN    NaN       NaN
# 11187      NaN        NaN                NaN        NaN    NaN       NaN
#
#          idtown  ... geopoint2longitude geopoint2altitude  geopoint2accuracy  \
# 0        SIENGA  ...          -10.62374             258.7                5.0
# 1       BAIWALA  ...                NaN               NaN                NaN
# 2       GBAHAMA  ...          -10.67104             248.3                5.0
# 3      BAIWALLA  ...          -10.64993             216.9                5.0
# 4      TAKPOIMA  ...          -10.66492             240.3                5.0
# ...         ...  ...                ...               ...                ...
# 11183       NaN  ...                NaN               NaN                NaN
# 11184       NaN  ...                NaN               NaN                NaN
# 11185       NaN  ...                NaN               NaN                NaN
# 11186       NaN  ...                NaN               NaN                NaN
# 11187      home  ...                NaN               NaN                NaN
#
#        comment_op formdef_version                                        key  \
# 0             NaN    1.906140e+09  uuid:5cb166c9-05bf-4b8a-94e9-6566c8ee4fcb
# 1             NaN    1.906140e+09  uuid:ca4fb19e-bed3-4a94-a0d4-c55b69f5d7c9
# 2             NaN    1.906140e+09  uuid:2872c576-f82e-4896-925a-ad22d1af54f4
# 3             NaN    1.906140e+09  uuid:4b782dd1-9796-4ee0-8f9f-e3902045efdb
# 4             NaN    1.906140e+09  uuid:7ff82373-9bbb-4c48-9150-f6081d8d326b
# ...           ...             ...                                        ...
# 11183         NaN             NaN                                        NaN
# 11184         NaN             NaN                                        NaN
# 11185         NaN             NaN                                        NaN
# 11186         NaN             NaN                                        NaN
# 11187         NaN             NaN                                        NaN
#
#         submissiondate        starttime          endtime             date
# 0       6/29/2019 0:25   6/24/2019 9:37  6/24/2019 10:06   6/24/2019 9:37
# 1       6/29/2019 0:25  6/24/2019 11:04  6/25/2019 22:08  6/25/2019 11:04
# 2      6/21/2019 22:50  6/19/2019 12:39  6/19/2019 13:30  6/19/2019 12:40
# 3       6/29/2019 0:25  6/25/2019 10:06  6/25/2019 10:35  6/25/2019 10:06
# 4      6/21/2019 22:50  6/19/2019 14:36  6/19/2019 15:32  6/19/2019 14:36
# ...                ...              ...              ...              ...
# 11183              NaN              NaN              NaN              NaN
# 11184              NaN              NaN              NaN              NaN
# 11185              NaN              NaN              NaN              NaN
# 11186              NaN              NaN              NaN              NaN
# 11187              NaN              NaN              NaN              NaN
#
# [11188 rows x 3764 columns]

# %%
# ^ Problem 1: there are 3764 columns in the source data. This makes it difficult to correctly map columns onto the unicef schema.
# The fuzzy matching in dataframe_cleaner will collect some of them.

# %%
# Problem 2: the 'date' values are not an ISO format, and also have NaN float values- so cannot be automatically parsed without formatting.
src_df['date']
# Out:
# 0         6/24/2019 9:37
# 1        6/25/2019 11:04
# 2        6/19/2019 12:40
# 3        6/25/2019 10:06
# 4        6/19/2019 14:36
#               ...
# 11183                NaN
# 11184                NaN
# 11185                NaN
# 11186                NaN
# 11187                NaN
# Name: date, Length: 11188, dtype: object

# %%
def fix_date(value):
    if not isinstance(value, str):
        return None
    return datetime.strptime(value, '%m/%d/%Y %H:%M')

# %%
preprocess_df = src_df
preprocess_df['date'] = preprocess_df['date'].apply(fix_date)
preprocess_df['date']
# Out:
# 0       2019-06-24 09:37:00
# 1       2019-06-25 11:04:00
# 2       2019-06-19 12:40:00
# 3       2019-06-25 10:06:00
# 4       2019-06-19 14:36:00
#                 ...
# 11183                   NaT
# 11184                   NaT
# 11185                   NaT
# 11186                   NaT
# 11187                   NaT
# Name: date, Length: 11188, dtype: datetime64[ns]

# %%
# run the dataframe_cleaner
country = countries.get('SL')
df = dataframe_cleaner(
    dataframe=preprocess_df,
    country=country,
    is_private=True,
    provider="ASC",
    provider_is_private=True
)
df
# Out:
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:copying dataframe...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:standardizing column names...
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:uuid column not found, generating uuid4
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:renaming columns: {'computers_number': 'num_computers',
#  'geopointaltitude': 'altitude',
#  'geopointlatitude': 'lat',
#  'geopointlongitude': 'lon',
#  'idschool_name': 'name',
#  'respondent_name': 'person_contact',
#  'sch_email': 'email',
#  'sch_type': 'educ_level',
#  'verify_district': 'admin3',
#  'water_source': 'water'}
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:adding 31 columns from schema: ['admin0',
#  'admin1',
#  'admin2',
#  'admin4',
#  'admin_code',
#  'admin_id',
#  'address',
#  'address2',
#  'phone_number',
#  'postal_code',
#  'gps_confidence',
#  'num_students',
#  'num_teachers',
#  'connectivity',
#  'type_connectivity',
#  'speed_connectivity',
#  'latency_connectivity',
#  'availability_connectivity',
#  'type_school',
#  'environment',
#  'num_classrooms',
#  'num_sections',
#  'num_latrines',
#  'description',
#  'last_update',
#  'tower_dist',
#  'tower_type_service',
#  'tower_type',
#  'tower_code',
#  'tower_latitude',
#  'tower_longitude']
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:removing columns: ['duration',
#  'enumerator',
#  'new_school',
#  'idregion',
#  'iddistrict',
#  'idcouncil',
#  'idchiefdom',
#  'idward',
#  'idsection',
#  'idtown',
#  'idemis_code',
#  'idunique_code',
#  'schoolinfo_correct',
#  'sch_infoupdate_specify',
#  'verify_region',
#  'verify_council',
#  'verify_chiefdom',
#  'verify_ward',
#  'verify_section',
#  'verify_village',
#  'verify_schoollevel',
#  'verify_schoolname',
#  'geopointaccuracy',
#  'photo1',
#  'school_status',
#  'res_designation',
#  'res_contact',
#  'sch_sid',
#  'waec_code',
#  'sch_founded',
#  'waeccode_ownership',
#  'accessibility',
#  'mobile_network',
#  'network_provider',
#  'orange_services_verify',
#  'africell_services_verify',
#  'sierratell_services_verify',
#  'qcell_services_verify',
#  'sch_owner',
#  'mixed_school',
#  'accomondation',
#  'total_teachers',
#  'total_pupils',
#  'total_classrooms',
#  'sch_mobile',
#  'sch_mobile_spfy',
#  'sch_email_spfy',
#  'boarding_boys',
#  'boarding_girls',
#  'boarding_schpupil_verify',
#  'shift_status',
#  'approval_status',
#  'fin_support',
#  'other_sch_usefacility',
#  'othsch_hwmany',
#  'repeat_othsch_particulars_count',
#  'oth_sch_level_1',
#  'oth_sch_name_1',
#  'oth_sch_emis_1',
#  'oth_sch_level_2',
#  'oth_sch_name_2',
#  'oth_sch_emis_2',
#  'oth_sch_level_3',
#  'oth_sch_name_3',
#  'oth_sch_emis_3',
#  'oth_sch_level_4',
#  'oth_sch_name_4',
#  'oth_sch_emis_4',
#  'oth_sch_level_5',
#  'oth_sch_name_5',
#  'oth_sch_emis_5',
#  'enrol_dc_below1_m',
#  'enrol_dc_below1_f',
#  'enrol_dc_1m',
#  'enrol_dc_1f',
#  'enrol_dc_2m',
#  'enrol_dc_2f',
#  'enrol_dc_3m',
#  'enrol_dc_3f',
#  'enrol_dc_4m',
#  'enrol_dc_4f',
#  'enrol_dc_5m',
#  'enrol_dc_5f',
#  'enrol_dc_above5_m',
#  'enrol_dc_above5_f',
#  'total_daycare_male',
#  'total_daycare_female',
#  'sum_enrol_daycare',
#  'note_sum_daycare',
#  'min_enrol_daycare',
#  'min_enrol_dc_confirm',
#  'enrol_nur1_below1_m',
#  'enrol_nur1_below1_f',
#  'enrol_nur1_1m',
#  'enrol_nur1_1f',
#  'enrol_nur1_2m',
#  'enrol_nur1_2f',
#  'enrol_nur1_3m',
#  'enrol_nur1_3f',
#  'enrol_nur1_4m',
#  'enrol_nur1_4f',
#  'enrol_nur1_5m',
#  'enrol_nur1_5f',
#  'enrol_nur1_above5_m',
#  'enrol_nur1_above5_f',
#  'total_nur1_male',
#  'total_nur1_female',
#  'sum_enrol_nur1',
#  'note_sum_nur1',
#  'min_enrol_nur1',
#  'min_enrol_nur1_confirm',
#  'enrol_nur2_below1_m',
#  'enrol_nur2_below1_f',
#  'enrol_nur2_1m',
#  'enrol_nur2_1f',
#  'enrol_nur2_2m',
#  'enrol_nur2_2f',
#  'enrol_nur2_3m',
#  'enrol_nur2_3f',
#  'enrol_nur2_4m',
#  'enrol_nur2_4f',
#  'enrol_nur2_5m',
#  'enrol_nur2_5f',
#  'enrol_nur2_above5_m',
#  'enrol_nur2_above5_f',
#  'total_nur2_male',
#  'total_nur2_female',
#  'sum_enrol_nur2',
#  'note_sum_nur2',
#  'min_enrol_nur2',
#  'min_enrol_nur2_confirm',
#  'enrol_nur3_below1_m',
#  'enrol_nur3_below1_f',
#  'enrol_nur3_1m',
#  'enrol_nur3_1f',
#  'enrol_nur3_2m',
#  'enrol_nur3_2f',
#  'enrol_nur3_3m',
#  'enrol_nur3_3f',
#  'enrol_nur3_4m',
#  'enrol_nur3_4f',
#  'enrol_nur3_5m',
#  'enrol_nur3_5f',
#  'enrol_nur3_above5_m',
#  'enrol_nur3_above5_f',
#  'total_nur3_male',
#  'total_nur3_female',
#  'sum_enrol_nur3',
#  'note_sum_nur3',
#  'min_enrol_nur3',
#  'min_enrol_nur3_confirm',
#  'total_nur_enrolmale',
#  'total_nur_enrolfemale',
#  'total_nur_enrolcombine',
#  'enrol_c1_below_5years_m',
#  'enrol_c1_below_5years_f',
#  'enrol_class1_5years_m',
#  'enrol_class1_5years_f',
#  'enrol_class1_6years_m',
#  'enrol_class1_6years_f',
#  'enrol_class1_7years_m',
#  'enrol_class1_7years_f',
#  'enrol_class1_8years_m',
#  'enrol_class1_8years_f',
#  'enrol_class1_9years_m',
#  'enrol_class1_9years_f',
#  'enrol_class1_10years_m',
#  'enrol_class1_10years_f',
#  'enrol_class1_11years_m',
#  'enrol_class1_11years_f',
#  'enrol_class1_12years_m',
#  'enrol_class1_12years_f',
#  'enrol_class1_13years_m',
#  'enrol_class1_13years_f',
#  'enrol_c1_above13years_m',
#  'enrol_c1_above13years_f',
#  'total_class1_male',
#  'total_class1_female',
#  'sum_enrol_class1',
#  'note_sum_class1',
#  'min_enrol_class1',
#  'min_enrol_class1_confirm',
#  'enrol_c2_below_5years_m',
#  'enrol_c2_below_5years_f',
#  'enrol_class2_5years_m',
#  'enrol_class2_5years_f',
#  'enrol_class2_6years_m',
#  'enrol_class2_6years_f',
#  'enrol_class2_7years_m',
#  'enrol_class2_7years_f',
#  'enrol_class2_8years_m',
#  'enrol_class2_8years_f',
#  'enrol_class2_9years_m',
#  'enrol_class2_9years_f',
#  'enrol_class2_10years_m',
#  'enrol_class2_10years_f',
#  'enrol_class2_11years_m',
#  'enrol_class2_11years_f',
#  'enrol_class2_12years_m',
#  'enrol_class2_12years_f',
#  'enrol_class2_13years_m',
#  'enrol_class2_13years_f',
#  'enrol_c2_above13years_m',
#  'enrol_c2_above13years_f',
#  'total_class2_male',
#  'total_class2_female',
#  'sum_enrol_class2',
#  'note_sum_class2',
#  'min_enrol_class2',
#  'min_enrol_class2_confirm',
#  'enrol_c3_below_5years_m',
#  'enrol_c3_below_5years_f',
#  'enrol_class3_5years_m',
#  'enrol_class3_5years_f',
#  'enrol_class3_6years_m',
#  'enrol_class3_6years_f',
#  'enrol_class3_7years_m',
#  'enrol_class3_7years_f',
#  'enrol_class3_8years_m',
#  'enrol_class3_8years_f',
#  'enrol_class3_9years_m',
#  'enrol_class3_9years_f',
#  'enrol_class3_10years_m',
#  'enrol_class3_10years_f',
#  'enrol_class3_11years_m',
#  'enrol_class3_11years_f',
#  'enrol_class3_12years_m',
#  'enrol_class3_12years_f',
#  'enrol_class3_13years_m',
#  'enrol_class3_13years_f',
#  'enrol_c3_above13years_m',
#  'enrol_c3_above13years_f',
#  'total_class3_male',
#  'total_class3_female',
#  'sum_enrol_class3',
#  'note_sum_class3',
#  'min_enrol_class3',
#  'min_enrol_class3_confirm',
#  'enrol_c4_below_5years_m',
#  'enrol_c4_below_5years_f',
#  'enrol_class4_5years_m',
#  'enrol_class4_5years_f',
#  'enrol_class4_6years_m',
#  'enrol_class4_6years_f',
#  'enrol_class4_7years_m',
#  'enrol_class4_7years_f',
#  'enrol_class4_8years_m',
#  'enrol_class4_8years_f',
#  'enrol_class4_9years_m',
#  'enrol_class4_9years_f',
#  'enrol_class4_10years_m',
#  'enrol_class4_10years_f',
#  'enrol_class4_11years_m',
#  'enrol_class4_11years_f',
#  'enrol_class4_12years_m',
#  'enrol_class4_12years_f',
#  'enrol_class4_13years_m',
#  'enrol_class4_13years_f',
#  'enrol_c4_above13years_m',
#  'enrol_c4_above13years_f',
#  'total_class4_male',
#  'total_class4_female',
#  'sum_enrol_class4',
#  'note_sum_class4',
#  'min_enrol_class4',
#  'min_enrol_class4_confirm',
#  'enrol_c5_below_5years_m',
#  'enrol_c5_below_5years_f',
#  'enrol_class5_5years_m',
#  'enrol_class5_5years_f',
#  'enrol_class5_6years_m',
#  'enrol_class5_6years_f',
#  'enrol_class5_7years_m',
#  'enrol_class5_7years_f',
#  'enrol_class5_8years_m',
#  'enrol_class5_8years_f',
#  'enrol_class5_9years_m',
#  'enrol_class5_9years_f',
#  'enrol_class5_10years_m',
#  'enrol_class5_10years_f',
#  'enrol_class5_11years_m',
#  'enrol_class5_11years_f',
#  'enrol_class5_12years_m',
#  'enrol_class5_12years_f',
#  'enrol_class5_13years_m',
#  'enrol_class5_13years_f',
#  'enrol_c5_above13years_m',
#  'enrol_c5_above13years_f',
#  'total_class5_male',
#  'total_class5_female',
#  'sum_enrol_class5',
#  'note_sum_class5',
#  'min_enrol_class5',
#  'min_enrol_class5_confirm',
#  'enrol_c6_below_5years_m',
#  'enrol_c6_below_5years_f',
#  'enrol_class6_5years_m',
#  'enrol_class6_5years_f',
#  'enrol_class6_6years_m',
#  'enrol_class6_6years_f',
#  'enrol_class6_7years_m',
#  'enrol_class6_7years_f',
#  'enrol_class6_8years_m',
#  'enrol_class6_8years_f',
#  'enrol_class6_9years_m',
#  'enrol_class6_9years_f',
#  'enrol_class6_10years_m',
#  'enrol_class6_10years_f',
#  'enrol_class6_11years_m',
#  'enrol_class6_11years_f',
#  'enrol_class6_12years_m',
#  'enrol_class6_12years_f',
#  'enrol_class6_13years_m',
#  'enrol_class6_13years_f',
#  'enrol_c6_above13years_m',
#  'enrol_c6_above13years_f',
#  'total_class6_male',
#  'total_class6_female',
#  'sum_enrol_class6',
#  'note_sum_class6',
#  'min_enrol_class6',
#  'min_enrol_class6_confirm',
#  'total_pri_enrolmale',
#  'total_pri_enrolfemale',
#  'total_pri_enrolcombine',
#  'enrol_j1_below_12years_m',
#  'enrol_j1_below_12years_f',
#  'enrol_jss1_12years_m',
#  'enrol_jss1_12years_f',
#  'enrol_jss1_13years_m',
#  'enrol_jss1_13years_f',
#  'enrol_jss1_14years_m',
#  'enrol_jss1_14years_f',
#  'enrol_jss1_15years_m',
#  'enrol_jss1_15years_f',
#  'enrol_jss1_16years_m',
#  'enrol_jss1_16years_f',
#  'enrol_jss1_17years_m',
#  'enrol_jss1_17years_f',
#  'enrol_j1_above17years_m',
#  'enrol_j1_above17years_f',
#  'total_jss1_male',
#  'total_jss1_female',
#  'sum_enrol_jss1',
#  'note_sum_jss1',
#  'min_enrol_jss1',
#  'min_enrol_jss1_confirm',
#  'enrol_j2_below_12years_m',
#  'enrol_j2_below_12years_f',
#  'enrol_jss2_12years_m',
#  'enrol_jss2_12years_f',
#  'enrol_jss2_13years_m',
#  'enrol_jss2_13years_f',
#  'enrol_jss2_14years_m',
#  'enrol_jss2_14years_f',
#  'enrol_jss2_15years_m',
#  'enrol_jss2_15years_f',
#  'enrol_jss2_16years_m',
#  'enrol_jss2_16years_f',
#  'enrol_jss2_17years_m',
#  'enrol_jss2_17years_f',
#  'enrol_j2_above17years_m',
#  'enrol_j2_above17years_f',
#  'total_jss2_male',
#  'total_jss2_female',
#  'sum_enrol_jss2',
#  'note_sum_jss2',
#  'min_enrol_jss2',
#  'min_enrol_jss2_confirm',
#  'enrol_j3_below_12years_m',
#  'enrol_j3_below_12years_f',
#  'enrol_jss3_12years_m',
#  'enrol_jss3_12years_f',
#  'enrol_jss3_13years_m',
#  'enrol_jss3_13years_f',
#  'enrol_jss3_14years_m',
#  'enrol_jss3_14years_f',
#  'enrol_jss3_15years_m',
#  'enrol_jss3_15years_f',
#  'enrol_jss3_16years_m',
#  'enrol_jss3_16years_f',
#  'enrol_jss3_17years_m',
#  'enrol_jss3_17years_f',
#  'enrol_j3_above17years_m',
#  'enrol_j3_above17years_f',
#  'total_jss3_male',
#  'total_jss3_female',
#  'sum_enrol_jss3',
#  'note_sum_jss3',
#  'min_enrol_jss3',
#  'min_enrol_jss3_confirm',
#  'total_jss_enrolmale',
#  'total_jss_enrolfemale',
#  'total_jss_enrolcombine',
#  'enrol_s1_below_15years_m',
#  'enrol_s1_below_15years_f',
#  'enrol_sss1_15years_m',
#  'enrol_sss1_15years_f',
#  'enrol_sss1_16years_m',
#  'enrol_sss1_16years_f',
#  'enrol_sss1_17years_m',
#  'enrol_sss1_17years_f',
#  'enrol_sss1_18years_m',
#  'enrol_sss1_18years_f',
#  'enrol_sss1_19years_m',
#  'enrol_sss1_19years_f',
#  'enrol_sss1_20years_m',
#  'enrol_sss1_20years_f',
#  'enrol_s1_above20years_m',
#  'enrol_s1_above20years_f',
#  'total_sss1_male',
#  'total_sss1_female',
#  'sum_enrol_sss1',
#  'note_sum_sss1',
#  'min_enrol_sss1',
#  'min_enrol_sss1_confirm',
#  'enrol_s2_below_15years_m',
#  'enrol_s2_below_15years_f',
#  'enrol_sss2_15years_m',
#  'enrol_sss2_15years_f',
#  'enrol_sss2_16years_m',
#  'enrol_sss2_16years_f',
#  'enrol_sss2_17years_m',
#  'enrol_sss2_17years_f',
#  'enrol_sss2_18years_m',
#  'enrol_sss2_18years_f',
#  'enrol_sss2_19years_m',
#  'enrol_sss2_19years_f',
#  'enrol_sss2_20years_m',
#  'enrol_sss2_20years_f',
#  'enrol_s2_above20years_m',
#  'enrol_s2_above20years_f',
#  'total_sss2_male',
#  'total_sss2_female',
#  'sum_enrol_sss2',
#  'note_sum_sss2',
#  'min_enrol_sss2',
#  'min_enrol_sss2_confirm',
#  'enrol_s3_below_15years_m',
#  'enrol_s3_below_15years_f',
#  'enrol_sss3_15years_m',
#  'enrol_sss3_15years_f',
#  'enrol_sss3_16years_m',
#  'enrol_sss3_16years_f',
#  'enrol_sss3_17years_m',
#  'enrol_sss3_17years_f',
#  'enrol_sss3_18years_m',
#  'enrol_sss3_18years_f',
#  'enrol_sss3_19years_m',
#  'enrol_sss3_19years_f',
#  'enrol_sss3_20years_m',
#  'enrol_sss3_20years_f',
#  'enrol_s3_above20years_m',
#  'enrol_s3_above20years_f',
#  'total_sss3_male',
#  'total_sss3_female',
#  'sum_enrol_sss3',
#  'note_sum_sss3',
#  'min_enrol_sss3',
#  'min_enrol_sss3_confirm',
#  'enrol_sspe3_below_15years_m',
#  'enrol_sspe3_below_15years_f',
#  'enrol_ssspe3_15years_m',
#  'enrol_ssspe3_15years_f',
#  'enrol_ssspe3_16years_m',
#  'enrol_ssspe3_16years_f',
#  'enrol_ssspe3_17years_m',
#  'enrol_ssspe3_17years_f',
#  'enrol_ssspe3_18years_m',
#  'enrol_ssspe3_18years_f',
#  'enrol_ssspe3_19years_m',
#  'enrol_ssspe3_19years_f',
#  'enrol_ssspe3_20years_m',
#  'enrol_ssspe3_20years_f',
#  'enrol_sspe3_above20years_m',
#  'enrol_sspe3_above20years_f',
#  'total_ssspe3_male',
#  'total_ssspe3_female',
#  'sum_enrol_ssspe3',
#  'note_sum_ssspe3',
#  'min_enrol_ssspe3',
#  'min_enrol_ssspe3_confirm',
#  'total_sss_enrolmale',
#  'total_sss_enrolfemale',
#  'total_sss_enrolcombine',
#  'enrol_daycare_male',
#  'enrol_daycare_female',
#  'enrol_nur1_male',
#  'enrol_nur1_female',
#  'enrol_nur2_male',
#  'enrol_nur2_female',
#  'enrol_nur3_male',
#  'enrol_nur3_female',
#  'enrolc0',
#  'enrolc1',
#  'enrolc2',
#  'enrolc3',
#  'sum_enrolnur',
#  'min_enrolnur',
#  'min_enrolnur1',
#  'enrol_class1_male',
#  'enrol_class1_female',
#  'enrol_class2_male',
#  'enrol_class2_female',
#  'enrol_class3_male',
#  'enrol_class3_female',
#  'enrol_class4_male',
#  'enrol_class4_female',
#  'enrol_class5_male',
#  'enrol_class5_female',
#  'enrol_class6_male',
#  'enrol_class6_female',
#  'enrolc4',
#  'enrolc5',
#  'enrolc6',
#  'enrolc7',
#  'enrolc8',
#  'enrolc9',
#  'sum_enrolpri',
#  'min_enrolpri',
#  'min_enrolpri1',
#  'enrol_jss1_male',
#  'enrol_jss1_female',
#  'enrol_jss2_male',
#  'enrol_jss2_female',
#  'enrol_jss3_male',
#  'enrol_jss3_female',
#  'enrolc10',
#  'enrolc11',
#  'enrolc12',
#  'sum_enroljss',
#  'min_enroljss',
#  'min_enroljss1',
#  'enrol_sss1_male',
#  'enrol_sss1_female',
#  'enrol_sss2_male',
#  'enrol_sss2_female',
#  'enrol_sss3_male',
#  'enrol_sss3_female',
#  'enrol_ssspe3_male',
#  'enrol_ssspe3_female',
#  'enrolc13',
#  'enrolc14',
#  'enrolc15',
#  'enrolc15spe',
#  'sum_enrolsss',
#  'min_enrolsss',
#  'min_enrolsss1',
#  'repeat_class1_male',
#  'repeat_class1_female',
#  'repeat_class2_male',
#  'repeat_class2_female',
#  'repeat_class3_male',
#  'repeat_class3_female',
#  'repeat_class4_male',
#  'repeat_class4_female',
#  'repeat_class5_male',
#  'repeat_class5_female',
#  'repeat_class6_male',
#  'repeat_class6_female',
#  'repeat_jss1_male',
#  'repeat_jss1_female',
#  'repeat_jss2_male',
#  'repeat_jss2_female',
#  'repeat_jss3_male',
#  'repeat_jss3_female',
#  'repeat_sss1_male',
#  'repeat_sss1_female',
#  'repeat_sss2_male',
#  'repeat_sss2_female',
#  'repeat_sss3_male',
#  'repeat_sss3_female',
#  'total_stream_nur4',
#  'total_stream_nur1',
#  'total_stream_nur2',
#  'total_stream_nur3',
#  'total_stream_class1',
#  'total_stream_class2',
#  'total_stream_class3',
#  'total_stream_class4',
#  'total_stream_class5',
#  'total_stream_class6',
#  'total_stream_jss1',
#  'total_stream_jss2',
#  'total_stream_jss3',
#  'total_stream_sss1',
#  'total_stream_sss2',
#  'total_stream_sss3',
#  'total_stream_ssspe3',
#  'nurse_min',
#  'nurse_min_confirm',
#  'nurse_tot',
#  'pri_min',
#  'pri_min_confirm',
#  'pri_tot',
#  'jss_min',
#  'jss_min_confirm',
#  'jss_tot',
#  'sss_min',
#  'sss_min_confirm',
#  'sss_tot',
#  'total_classrooms_nur4',
#  'total_classrooms_nur1',
#  'total_classrooms_nur2',
#  'total_classrooms_nur3',
#  'total_classrooms_class1',
#  'total_classrooms_class2',
#  'total_classrooms_class3',
#  'total_classrooms_class4',
#  'total_classrooms_class5',
#  'total_classrooms_class6',
#  'total_classrooms_jss1',
#  'total_classrooms_jss2',
#  'total_classrooms_jss3',
#  'total_classrooms_sss1',
#  'total_classrooms_sss2',
#  'total_classrooms_sss3',
#  'total_classrooms_ssspe3',
#  'nurse_croom_min',
#  'nurse_croom_min_confirm',
#  'nurse_croom_tot',
#  'nurse_croom_tot_confirm',
#  'pri_croom_min',
#  'pri_croom_min_confirm',
#  'pri_croom_tot',
#  'pri_croom_tot_confirm',
#  'jss_croom_min',
#  'jss_croom_min_confirm',
#  'jss_croom_tot',
#  'jss_croom_tot_confirm',
#  'sss_croom_min',
#  'sss_croom_min_confirm',
#  'sss_croom_tot',
#  'sss_croom_tot_confirm',
#  'total_withoutseat_nur4',
#  'total_withoutseat_nur1',
#  'total_withoutseat_nur2',
#  'total_withoutseat_nur3',
#  'total_withoutseat_class1',
#  'total_withoutseat_class2',
#  'total_withoutseat_class3',
#  'total_withoutseat_class4',
#  'total_withoutseat_class5',
#  'total_withoutseat_class6',
#  'total_withoutseat_jss1',
#  'total_withoutseat_jss2',
#  'total_withoutseat_jss3',
#  'total_withoutseat_sss1',
#  'total_withoutseat_sss2',
#  'total_withoutseat_sss3',
#  'total_withoutseat_ssspe3',
#  'nurse_woutseat_min',
#  'nurse_woutseat_min_confirm',
#  'nurse_woutseat_tot',
#  'nurse_woutseat_tot_confirm',
#  'pri_woutseat_min',
#  'pri_woutseat_min_confirm',
#  'pri_woutseat_tot',
#  'pri_woutseat_tot_confirm',
#  'jss_woutseat_min',
#  'jss_woutseat_min_confirm',
#  'jss_woutseat_tot',
#  'jss_woutseat_tot_confirm',
#  'sss_woutseat_min',
#  'sss_woutseat_min_confirm',
#  'sss_woutseat_tot',
#  'sss_woutseat_tot_confirm',
#  'enrollessrepeat_c1m',
#  'enrollessrepeat_c1f',
#  'new_c1_below_6years_m',
#  'new_c1_below_6years_f',
#  'new_class1_6years_m',
#  'new_class1_6years_f',
#  'new_class1_7years_m',
#  'new_class1_7years_f',
#  'new_class1_8years_m',
#  'new_class1_8years_f',
#  'new_class1_9years_m',
#  'new_class1_9years_f',
#  'new_c1_above9years_m',
#  'new_c1_above9years_f',
#  'total_newclass1_male',
#  'total_newclass1_female',
#  'sum_new_class1',
#  'min_new_class1',
#  'min_new_class1_confirm',
#  'trans_class2_male',
#  'trans_class2_female',
#  'trans_class3_male',
#  'trans_class3_female',
#  'trans_class4_male',
#  'trans_class4_female',
#  'trans_class5_male',
#  'trans_class5_female',
#  'trans_class6_male',
#  'trans_class6_female',
#  'transc5',
#  'transc6',
#  'transc7',
#  'transc8',
#  'transc9',
#  'sum_transpri',
#  'min_transpri',
#  'min_transpri1',
#  'enrollessrepeat_jss1m',
#  'enrollessrepeat_jss1f',
#  'new_j1_below_12years_m',
#  'new_j1_below_12years_f',
#  'new_jss1_12years_m',
#  'new_jss1_12years_f',
#  'new_j1_above12years_m',
#  'new_j1_above12years_f',
#  'total_newjss1_male',
#  'total_newjss1_female',
#  'sum_new_jss1',
#  'min_new_jss1',
#  'min_new_jss1_confirm',
#  'trans_jss2_male',
#  'trans_jss2_female',
#  'trans_jss3_male',
#  'trans_jss3_female',
#  'transc11',
#  'transc12',
#  'sum_transjss',
#  'min_transjss',
#  'min_transjss1',
#  'enrollessrepeat_sss1m',
#  'enrollessrepeat_sss1f',
#  'new_s1_below_15years_m',
#  'new_s1_below_15years_f',
#  'new_sss1_15years_m',
#  'new_sss1_15years_f',
#  'new_sss1_16years_m',
#  'new_sss1_16years_f',
#  'new_s1_above16years_m',
#  'new_s1_above16years_f',
#  'total_newsss1_male',
#  'total_newsss1_female',
#  'sum_new_sss1',
#  'min_new_sss1',
#  'min_new_sss1_confirm',
#  'trans_sss2_male',
#  'trans_sss2_female',
#  'trans_sss3_male',
#  'trans_sss3_female',
#  'trans_ssspe3_male',
#  'trans_ssspe3_female',
#  'transc14',
#  'transc15',
#  'transc15spe',
#  'sum_transsss',
#  'min_transsss',
#  'min_transsss1',
#  'disability',
#  'disability_type',
#  'disability_visual',
#  'disability_hearing',
#  'disability_speech',
#  'disability_physical',
#  'disability_learning',
#  'disability_class_nur',
#  'disability_class_pri',
#  'disability_class_jss',
#  'disability_class_sss',
#  'visual_daycare_male',
#  'visual_daycare_female',
#  'hearing_daycare_male',
#  'hearing_daycare_female',
#  'speech_daycare_male',
#  'speech_daycare_female',
#  'physical_daycare_male',
#  'physical_daycare_female',
#  'learning_daycare_male',
#  'learning_daycare_female',
#  'visual_nur1_male',
#  'visual_nur1_female',
#  'hearing_nur1_male',
#  'hearing_nur1_female',
#  'speech_nur1_male',
#  'speech_nur1_female',
#  'physical_nur1_male',
#  'physical_nur1_female',
#  'learning_nur1_male',
#  'learning_nur1_female',
#  'visual_nur2_male',
#  'visual_nur2_female',
#  'hearing_nur2_male',
#  'hearing_nur2_female',
#  'speech_nur2_male',
#  'speech_nur2_female',
#  'physical_nur2_male',
#  'physical_nur2_female',
#  'learning_nur2_male',
#  'learning_nur2_female',
#  'visual_nur3_male',
#  'visual_nur3_female',
#  'hearing_nur3_male',
#  'hearing_nur3_female',
#  'speech_nur3_male',
#  'speech_nur3_female',
#  'physical_nur3_male',
#  'physical_nur3_female',
#  'learning_nur3_male',
#  'learning_nur3_female',
#  'totalnur_visual_male',
#  'totalnur_visual_female',
#  'totalnur_hearing_male',
#  'totalnur_hearing_female',
#  'totalnur_speech_male',
#  'totalnur_speech_female',
#  'totalnur_physical_male',
#  'totalnur_physical_female',
#  'totalnur_learning_male',
#  'totalnur_learning_female',
#  'totalnur_sneeds_male',
#  'totalnur_sneeds_female',
#  'totalnur_sneeds_combined',
#  'totalnur_sneeds_male_confirm',
#  'totalnur_sneeds_female_confirm',
#  'totalnur_sneeds_combine_confirm',
#  'visual_class1_male',
#  'visual_class1_female',
#  'hearing_class1_male',
#  'hearing_class1_female',
#  'speech_class1_male',
#  'speech_class1_female',
#  'physical_class1_male',
#  'physical_class1_female',
#  'learning_class1_male',
#  'learning_class1_female',
#  'visual_class2_male',
#  'visual_class2_female',
#  'hearing_class2_male',
#  'hearing_class2_female',
#  'speech_class2_male',
#  'speech_class2_female',
#  'physical_class2_male',
#  'physical_class2_female',
#  'learning_class2_male',
#  'learning_class2_female',
#  'visual_class3_male',
#  'visual_class3_female',
#  'hearing_class3_male',
#  'hearing_class3_female',
#  'speech_class3_male',
#  'speech_class3_female',
#  'physical_class3_male',
#  'physical_class3_female',
#  'learning_class3_male',
#  'learning_class3_female',
#  'visual_class4_male',
#  'visual_class4_female',
#  'hearing_class4_male',
#  'hearing_class4_female',
#  'speech_class4_male',
#  'speech_class4_female',
#  'physical_class4_male',
#  'physical_class4_female',
#  'learning_class4_male',
#  'learning_class4_female',
#  'visual_class5_male',
#  'visual_class5_female',
#  'hearing_class5_male',
#  'hearing_class5_female',
#  'speech_class5_male',
#  'speech_class5_female',
#  'physical_class5_male',
#  'physical_class5_female',
#  'learning_class5_male',
#  'learning_class5_female',
#  'visual_class6_male',
#  'visual_class6_female',
#  'hearing_class6_male',
#  'hearing_class6_female',
#  'speech_class6_male',
#  'speech_class6_female',
#  'physical_class6_male',
#  'physical_class6_female',
#  'learning_class6_male',
#  'learning_class6_female',
#  'totalpri_visual_male',
#  'totalpri_visual_female',
#  'totalpri_hearing_male',
#  'totalpri_hearing_female',
#  'totalpri_speech_male',
#  'totalpri_speech_female',
#  'totalpri_physical_male',
#  'totalpri_physical_female',
#  'totalpri_learning_male',
#  'totalpri_learning_female',
#  'totalpri_sneeds_male',
#  'totalpri_sneeds_female',
#  'totalpri_sneeds_combined',
#  'totalpri_sneeds_male_confirm',
#  'totalpri_sneeds_female_confirm',
#  'totalpri_sneeds_combine_confirm',
#  'visual_jss1_male',
#  'visual_jss1_female',
#  'hearing_jss1_male',
#  'hearing_jss1_female',
#  'speech_jss1_male',
#  'speech_jss1_female',
#  'physical_jss1_male',
#  'physical_jss1_female',
#  'learning_jss1_male',
#  'learning_jss1_female',
#  'visual_jss2_male',
#  'visual_jss2_female',
#  'hearing_jss2_male',
#  'hearing_jss2_female',
#  'speech_jss2_male',
#  'speech_jss2_female',
#  'physical_jss2_male',
#  'physical_jss2_female',
#  'learning_jss2_male',
#  'learning_jss2_female',
#  'visual_jss3_male',
#  'visual_jss3_female',
#  'hearing_jss3_male',
#  'hearing_jss3_female',
#  'speech_jss3_male',
#  'speech_jss3_female',
#  'physical_jss3_male',
#  'physical_jss3_female',
#  'learning_jss3_male',
#  'learning_jss3_female',
#  'totaljss_visual_male',
#  'totaljss_visual_female',
#  'totaljss_hearing_male',
#  'totaljss_hearing_female',
#  'totaljss_speech_male',
#  'totaljss_speech_female',
#  'totaljss_physical_male',
#  'totaljss_physical_female',
#  'totaljss_learning_male',
#  'totaljss_learning_female',
#  'totaljss_sneeds_male',
#  'totaljss_sneeds_female',
#  'totaljss_sneeds_combined',
#  'totaljss_sneeds_male_confirm',
#  'totaljss_sneeds_female_confirm',
#  'totaljss_sneeds_combine_confirm',
#  'visual_sss1_male',
#  'visual_sss1_female',
#  'hearing_sss1_male',
#  'hearing_sss1_female',
#  'speech_sss1_male',
#  'speech_sss1_female',
#  'physical_sss1_male',
#  'physical_sss1_female',
#  'learning_sss1_male',
#  'learning_sss1_female',
#  'visual_sss2_male',
#  'visual_sss2_female',
#  'hearing_sss2_male',
#  'hearing_sss2_female',
#  'speech_sss2_male',
#  'speech_sss2_female',
#  'physical_sss2_male',
#  'physical_sss2_female',
#  'learning_sss2_male',
#  'learning_sss2_female',
#  'visual_sss3_male',
#  'visual_sss3_female',
#  'hearing_sss3_male',
#  'hearing_sss3_female',
#  'speech_sss3_male',
#  'speech_sss3_female',
#  'physical_sss3_male',
#  'physical_sss3_female',
#  'learning_sss3_male',
#  'learning_sss3_female',
#  'visual_sss3sp_male',
#  'visual_sss3sp_female',
#  'hearing_sss3sp_male',
#  'hearing_sss3sp_female',
#  'speech_sss3sp_male',
#  'speech_sss3sp_female',
#  'physical_sss3sp_male',
#  'physical_sss3sp_female',
#  'learning_sss3sp_male',
#  'learning_sss3sp_female',
#  'totalsss_visual_male',
#  'totalsss_visual_female',
#  'totalsss_hearing_male',
#  'totalsss_hearing_female',
#  'totalsss_speech_male',
#  'totalsss_speech_female',
#  'totalsss_physical_male',
#  'totalsss_physical_female',
#  'totalsss_learning_male',
#  'totalsss_learning_female',
#  'totalsss_sneeds_male',
#  'totalsss_sneeds_female',
#  'totalsss_sneeds_combined',
#  'totalsss_sneeds_male_confirm',
#  'totalsss_sneeds_female_confirm',
#  'totalsss_sneeds_combine_confirm',
#  'daycare_instrmaterials',
#  'nur1_instrmaterials',
#  'nur2_instrmaterials',
#  'nur3_instrmaterials',
#  'langmaterials_class1',
#  'langmaterials_class2',
#  'langmaterials_class3',
#  'langmaterials_class4',
#  'langmaterials_class5',
#  'langmaterials_class6',
#  'totalpri_langmaterials',
#  'totalpri_langmat_confirm',
#  'mathmaterials_class1',
#  'mathmaterials_class2',
#  'mathmaterials_class3',
#  'mathmaterials_class4',
#  'mathmaterials_class5',
#  'mathmaterials_class6',
#  'totalpri_mathmaterials',
#  'totalpri_mathmat_confirm',
#  'scimaterials_class1',
#  'scimaterials_class2',
#  'scimaterials_class3',
#  'scimaterials_class4',
#  'scimaterials_class5',
#  'scimaterials_class6',
#  'totalpri_scimaterials',
#  'totalpri_scimat_confirm',
#  'sosmaterials_class1',
#  'sosmaterials_class2',
#  'sosmaterials_class3',
#  'sosmaterials_class4',
#  'sosmaterials_class5',
#  'sosmaterials_class6',
#  'totalpri_sosmaterials',
#  'totalpri_sosmat_confirm',
#  'langmaterials_jss1',
#  'langmaterials_jss2',
#  'langmaterials_jss3',
#  'totaljss_langmaterials',
#  'totaljss_langmat_confirm',
#  'mathmaterials_jss1',
#  'mathmaterials_jss2',
#  'mathmaterials_jss3',
#  'totaljss_mathmaterials',
#  'totaljss_mathmat_confirm',
#  'intgrtmaterials_jss1',
#  'intgrtmaterials_jss2',
#  'intgrtmaterials_jss3',
#  'totaljss_intgrtmaterials',
#  'totaljss_intgrtmat_confirm',
#  'sosmaterials_jss1',
#  'sosmaterials_jss2',
#  'sosmaterials_jss3',
#  'totaljss_sosmaterials',
#  'totaljss_sosmat_confirm',
#  'othmaterials_jss1',
#  'othmaterials_jss2',
#  'othmaterials_jss3',
#  'totaljss_othmaterials',
#  'totaljss_othmat_confirm',
#  'engmaterials_sss1',
#  'engmaterials_sss2',
#  'engmaterials_sss3',
#  'engmaterials_ssspe3',
#  'totalsss_engmaterials',
#  'totalsss_engmat_confirm',
#  'mathmaterials_sss1',
#  'mathmaterials_sss2',
#  'mathmaterials_sss3',
#  'mathmaterials_ssspe3',
#  'totalsss_mathmaterials',
#  'totalsss_mathmat_confirm',
#  'scimaterials_sss1',
#  'scimaterials_sss2',
#  'scimaterials_sss3',
#  'scimaterials_ssspe3',
#  'totalsss_scimaterials',
#  'totalsss_scimat_confirm',
#  'artsmaterials_sss1',
#  'artsmaterials_sss2',
#  'artsmaterials_sss3',
#  'artsmaterials_ssspe3',
#  'totalsss_artsmaterials',
#  'totalsss_artsmat_confirm',
#  'commaterials_sss1',
#  'commaterials_sss2',
#  'commaterials_sss3',
#  'commaterials_ssspe3',
#  'totalsss_commaterials',
#  'totalsss_commat_confirm',
#  'electricity_oth',
#  'water_source_oth',
#  'computers',
#  'internet',
#  'basic_comp_skills',
#  'comp_trainedteachers',
#  'enrol_comp_boys',
#  'enrol_comp_girls',
#  'teacher_comp_males',
#  'teacher_comp_females',
#  'cal_comp_skills',
#  'note_c_3',
#  'sch_feeding',
#  'feeding_wktimes',
#  'teacher_houses',
#  'teacher_houses_hwmany',
#  'avail_hand_wash',
#  'sch_garden',
#  'sch_fenced',
#  'playing_field',
#  'disable_ramp',
#  'disability_latrines',
#  'girls_cubicle',
#  'hiv_education',
#  'library',
#  'science_lab',
#  'good_girls_latrine',
#  'good_boys_latrine',
#  'good_shared_latrine',
#  'sum_good_latrines',
#  'good_latrines_confirm',
#  'fair_girls_latrine',
#  'fair_boys_latrine',
#  'fair_shared_latrine',
#  'sum_fair_latrines',
#  'fair_latrines_confirm',
#  'bad_girls_latrine',
#  'bad_boys_latrine',
#  'bad_shared_latrine',
#  'sum_bad_latrines',
#  'bad_latrines_confirm',
#  'teacher_girls_latrine',
#  'teacher_boys_latrine',
#  'teacher_shared_latrine',
#  'sum_teacher_latrines',
#  'teacher_latrines_confirm',
#  'solid_class',
#  'solid_class_repair',
#  'semi_solid_class',
#  'semi_solid_class_repair',
#  'make_shift_class',
#  'make_shift_class_repair',
#  'other_class',
#  'other_class_repair',
#  'sum_good_classrooms',
#  'sum_repair_classrooms',
#  'class_tot_verify',
#  'min_fin_resources',
#  'pbf_grants_resources',
#  'parentcom_resources',
#  'chuchmosque_resources',
#  'oth_fin_resources',
#  'total_fin_resources',
#  'sum_fin_resources',
#  'expend_payrolllsalary',
#  'expend_norpayrollsalary',
#  'expend_meal',
#  'expend_watsan',
#  'expend_learningmat',
#  'expend_matsupport',
#  'expend_rehab',
#  'expenditures',
#  'nur_lang_instruct',
#  'pri_lang_instruct',
#  'non_teaching_staff',
#  'non_teaching_staff_hwmany',
#  'guidance_counsellor',
#  'func_mothersclub',
#  'cta',
#  'cta_meeting_number',
#  'sch_dev_plan',
#  'smc',
#  'smc_meeting_number',
#  'smc_training',
#  'teachers_howmany',
#  'teachers_govt_m',
#  'teachers_govt_f',
#  'teachers_nongovt_m',
#  'teachers_nongovt_f',
#  'teachers_volunteers_m',
#  'teachers_volunteers_f',
#  'verify_teacher',
#  'repeat_staff_edu_count',
#  'teacherid_1',
#  'teacher_surname_1',
#  'teacher_name_1',
#  'new_teacher_1',
#  'teacher_nin_1',
#  'teacher_sex_1',
#  'teacher_time_1',
#  'teacher_age_1',
#  'teacher_payroll_num_1',
#  'teacher_current_position_1',
#  'teacher_current_position2_1',
#  'class_teacher_1',
#  'agetoservice_1',
#  'service_years_1',
#  'teacher_prof_qual_1',
#  'teacher_aca_qual_1',
#  'teacher_subj_specialty_pre_1',
#  'teacher_subj_specialty_pri_1',
#  'teacher_subj_specialty_jss_1',
#  'teacher_subj_specialty_sss_1',
#  'teacher_subj_taught_pre_1',
#  'teacher_subj_taught_pri_1',
#  'teacher_subj_taught_jss_1',
#  'teacher_subj_taught_sss_1',
#  'teacher_class_taught_preprimary_',
#  'teacher_class_taught_primary_1',
#  'teacher_class_taught_jss_1',
#  'teacher_class_taught_sss_1',
#  'hours_taught_1',
#  'teacher_salary_source_1',
#  'teacher_grade_level_1',
#  'concat_teacher_id_1',
#  'concat_teacher_id2_1',
#  'concat_teacher_id_new_1',
#  'teacherid_2',
#  'teacher_surname_2',
#  'teacher_name_2',
#  'new_teacher_2',
#  'teacher_nin_2',
#  'teacher_sex_2',
#  'teacher_time_2',
#  'teacher_age_2',
#  'teacher_payroll_num_2',
#  'teacher_current_position_2',
#  'teacher_current_position2_2',
#  'class_teacher_2',
#  'agetoservice_2',
#  'service_years_2',
#  'teacher_prof_qual_2',
#  'teacher_aca_qual_2',
#  'teacher_subj_specialty_pre_2',
#  'teacher_subj_specialty_pri_2',
#  'teacher_subj_specialty_jss_2',
#  'teacher_subj_specialty_sss_2',
#  'teacher_subj_taught_pre_2',
#  'teacher_subj_taught_pri_2',
#  'teacher_subj_taught_jss_2',
#  'teacher_subj_taught_sss_2',
#  'v1408',
#  'teacher_class_taught_primary_2',
#  'teacher_class_taught_jss_2',
#  'teacher_class_taught_sss_2',
#  'hours_taught_2',
#  'teacher_salary_source_2',
#  'teacher_grade_level_2',
#  'concat_teacher_id_2',
#  'concat_teacher_id2_2',
#  'concat_teacher_id_new_2',
#  'teacherid_3',
#  'teacher_surname_3',
#  'teacher_name_3',
#  'new_teacher_3',
#  'teacher_nin_3',
#  'teacher_sex_3',
#  'teacher_time_3',
#  'teacher_age_3',
#  'teacher_payroll_num_3',
#  'teacher_current_position_3',
#  'teacher_current_position2_3',
#  'class_teacher_3',
#  'agetoservice_3',
#  'service_years_3',
#  'teacher_prof_qual_3',
#  'teacher_aca_qual_3',
#  'teacher_subj_specialty_pre_3',
#  'teacher_subj_specialty_pri_3',
#  'teacher_subj_specialty_jss_3',
#  'teacher_subj_specialty_sss_3',
#  'teacher_subj_taught_pre_3',
#  'teacher_subj_taught_pri_3',
#  'teacher_subj_taught_jss_3',
#  'teacher_subj_taught_sss_3',
#  'v1446',
#  'teacher_class_taught_primary_3',
#  'teacher_class_taught_jss_3',
#  'teacher_class_taught_sss_3',
#  'hours_taught_3',
#  'teacher_salary_source_3',
#  'teacher_grade_level_3',
#  'concat_teacher_id_3',
#  'concat_teacher_id2_3',
#  'concat_teacher_id_new_3',
#  'teacherid_4',
#  'teacher_surname_4',
#  'teacher_name_4',
#  'new_teacher_4',
#  'teacher_nin_4',
#  'teacher_sex_4',
#  'teacher_time_4',
#  'teacher_age_4',
#  'teacher_payroll_num_4',
#  'teacher_current_position_4',
#  'teacher_current_position2_4',
#  'class_teacher_4',
#  'agetoservice_4',
#  'service_years_4',
#  'teacher_prof_qual_4',
#  'teacher_aca_qual_4',
#  'teacher_subj_specialty_pre_4',
#  'teacher_subj_specialty_pri_4',
#  'teacher_subj_specialty_jss_4',
#  'teacher_subj_specialty_sss_4',
#  'teacher_subj_taught_pre_4',
#  'teacher_subj_taught_pri_4',
#  'teacher_subj_taught_jss_4',
#  'teacher_subj_taught_sss_4',
#  'v1484',
#  'teacher_class_taught_primary_4',
#  'teacher_class_taught_jss_4',
#  'teacher_class_taught_sss_4',
#  'hours_taught_4',
#  'teacher_salary_source_4',
#  'teacher_grade_level_4',
#  'concat_teacher_id_4',
#  'concat_teacher_id2_4',
#  'concat_teacher_id_new_4',
#  'teacherid_5',
#  'teacher_surname_5',
#  'teacher_name_5',
#  'new_teacher_5',
#  'teacher_nin_5',
#  'teacher_sex_5',
#  'teacher_time_5',
#  'teacher_age_5',
#  'teacher_payroll_num_5',
#  'teacher_current_position_5',
#  'teacher_current_position2_5',
#  'class_teacher_5',
#  'agetoservice_5',
#  'service_years_5',
#  'teacher_prof_qual_5',
#  'teacher_aca_qual_5',
#  'teacher_subj_specialty_pre_5',
#  'teacher_subj_specialty_pri_5',
#  'teacher_subj_specialty_jss_5',
#  'teacher_subj_specialty_sss_5',
#  'teacher_subj_taught_pre_5',
#  'teacher_subj_taught_pri_5',
#  'teacher_subj_taught_jss_5',
#  'teacher_subj_taught_sss_5',
#  'v1522',
#  'teacher_class_taught_primary_5',
#  'teacher_class_taught_jss_5',
#  'teacher_class_taught_sss_5',
#  'hours_taught_5',
#  'teacher_salary_source_5',
#  'teacher_grade_level_5',
#  'concat_teacher_id_5',
#  'concat_teacher_id2_5',
#  'concat_teacher_id_new_5',
#  'teacherid_6',
#  'teacher_surname_6',
#  'teacher_name_6',
#  'new_teacher_6',
#  'teacher_nin_6',
#  'teacher_sex_6',
#  'teacher_time_6',
#  'teacher_age_6',
#  'teacher_payroll_num_6',
#  'teacher_current_position_6',
#  'teacher_current_position2_6',
#  'class_teacher_6',
#  'agetoservice_6',
#  'service_years_6',
#  'teacher_prof_qual_6',
#  'teacher_aca_qual_6',
#  'teacher_subj_specialty_pre_6',
#  'teacher_subj_specialty_pri_6',
#  'teacher_subj_specialty_jss_6',
#  'teacher_subj_specialty_sss_6',
#  'teacher_subj_taught_pre_6',
#  'teacher_subj_taught_pri_6',
#  'teacher_subj_taught_jss_6',
#  'teacher_subj_taught_sss_6',
#  'v1560',
#  'teacher_class_taught_primary_6',
#  'teacher_class_taught_jss_6',
#  'teacher_class_taught_sss_6',
#  'hours_taught_6',
#  'teacher_salary_source_6',
#  'teacher_grade_level_6',
#  'concat_teacher_id_6',
#  'concat_teacher_id2_6',
#  'concat_teacher_id_new_6',
#  'teacherid_7',
#  'teacher_surname_7',
#  'teacher_name_7',
#  'new_teacher_7',
#  'teacher_nin_7',
#  'teacher_sex_7',
#  'teacher_time_7',
#  'teacher_age_7',
#  'teacher_payroll_num_7',
#  'teacher_current_position_7',
#  'teacher_current_position2_7',
#  'class_teacher_7',
#  'agetoservice_7',
#  'service_years_7',
#  'teacher_prof_qual_7',
#  'teacher_aca_qual_7',
#  'teacher_subj_specialty_pre_7',
#  'teacher_subj_specialty_pri_7',
#  'teacher_subj_specialty_jss_7',
#  'teacher_subj_specialty_sss_7',
#  'teacher_subj_taught_pre_7',
#  'teacher_subj_taught_pri_7',
#  'teacher_subj_taught_jss_7',
#  'teacher_subj_taught_sss_7',
#  'v1598',
#  'teacher_class_taught_primary_7',
#  'teacher_class_taught_jss_7',
#  'teacher_class_taught_sss_7',
#  'hours_taught_7',
#  'teacher_salary_source_7',
#  'teacher_grade_level_7',
#  'concat_teacher_id_7',
#  'concat_teacher_id2_7',
#  'concat_teacher_id_new_7',
#  'teacherid_8',
#  'teacher_surname_8',
#  'teacher_name_8',
#  'new_teacher_8',
#  'teacher_nin_8',
#  'teacher_sex_8',
#  'teacher_time_8',
#  'teacher_age_8',
#  'teacher_payroll_num_8',
#  'teacher_current_position_8',
#  'teacher_current_position2_8',
#  'class_teacher_8',
#  'agetoservice_8',
#  'service_years_8',
#  'teacher_prof_qual_8',
#  'teacher_aca_qual_8',
#  'teacher_subj_specialty_pre_8',
#  'teacher_subj_specialty_pri_8',
#  'teacher_subj_specialty_jss_8',
#  'teacher_subj_specialty_sss_8',
#  'teacher_subj_taught_pre_8',
#  'teacher_subj_taught_pri_8',
#  'teacher_subj_taught_jss_8',
#  'teacher_subj_taught_sss_8',
#  'v1636',
#  'teacher_class_taught_primary_8',
#  'teacher_class_taught_jss_8',
#  'teacher_class_taught_sss_8',
#  'hours_taught_8',
#  'teacher_salary_source_8',
#  'teacher_grade_level_8',
#  'concat_teacher_id_8',
#  'concat_teacher_id2_8',
#  'concat_teacher_id_new_8',
#  'teacherid_9',
#  'teacher_surname_9',
#  'teacher_name_9',
#  'new_teacher_9',
#  'teacher_nin_9',
#  'teacher_sex_9',
#  'teacher_time_9',
#  'teacher_age_9',
#  'teacher_payroll_num_9',
#  'teacher_current_position_9',
#  'teacher_current_position2_9',
#  'class_teacher_9',
#  'agetoservice_9',
#  'service_years_9',
#  'teacher_prof_qual_9',
#  'teacher_aca_qual_9',
#  'teacher_subj_specialty_pre_9',
#  'teacher_subj_specialty_pri_9',
#  'teacher_subj_specialty_jss_9',
#  'teacher_subj_specialty_sss_9',
#  'teacher_subj_taught_pre_9',
#  'teacher_subj_taught_pri_9',
#  'teacher_subj_taught_jss_9',
#  'teacher_subj_taught_sss_9',
#  'v1674',
#  'teacher_class_taught_primary_9',
#  'teacher_class_taught_jss_9',
#  'teacher_class_taught_sss_9',
#  'hours_taught_9',
#  'teacher_salary_source_9',
#  'teacher_grade_level_9',
#  'concat_teacher_id_9',
#  'concat_teacher_id2_9',
#  'concat_teacher_id_new_9',
#  'teacherid_10',
#  'teacher_surname_10',
#  'teacher_name_10',
#  'new_teacher_10',
#  'teacher_nin_10',
#  'teacher_sex_10',
#  'teacher_time_10',
#  'teacher_age_10',
#  'teacher_payroll_num_10',
#  'teacher_current_position_10',
#  'teacher_current_position2_10',
#  'class_teacher_10',
#  'agetoservice_10',
#  'service_years_10',
#  'teacher_prof_qual_10',
#  'teacher_aca_qual_10',
#  'teacher_subj_specialty_pre_10',
#  'teacher_subj_specialty_pri_10',
#  'teacher_subj_specialty_jss_10',
#  'teacher_subj_specialty_sss_10',
#  'teacher_subj_taught_pre_10',
#  'teacher_subj_taught_pri_10',
#  'teacher_subj_taught_jss_10',
#  'teacher_subj_taught_sss_10',
#  'v1712',
#  'teacher_class_taught_primary_10',
#  'teacher_class_taught_jss_10',
#  'teacher_class_taught_sss_10',
#  'hours_taught_10',
#  'teacher_salary_source_10',
#  'teacher_grade_level_10',
#  'concat_teacher_id_10',
#  'concat_teacher_id2_10',
#  'concat_teacher_id_new_10',
#  'teacherid_11',
#  'teacher_surname_11',
#  'teacher_name_11',
#  'new_teacher_11',
#  'teacher_nin_11',
#  'teacher_sex_11',
#  'teacher_time_11',
#  'teacher_age_11',
#  'teacher_payroll_num_11',
#  'teacher_current_position_11',
#  'teacher_current_position2_11',
#  'class_teacher_11',
#  'agetoservice_11',
#  'service_years_11',
#  'teacher_prof_qual_11',
#  'teacher_aca_qual_11',
#  'teacher_subj_specialty_pre_11',
#  'teacher_subj_specialty_pri_11',
#  'teacher_subj_specialty_jss_11',
#  'teacher_subj_specialty_sss_11',
#  'teacher_subj_taught_pre_11',
#  'teacher_subj_taught_pri_11',
#  'teacher_subj_taught_jss_11',
#  'teacher_subj_taught_sss_11',
#  'v1750',
#  'teacher_class_taught_primary_11',
#  'teacher_class_taught_jss_11',
#  'teacher_class_taught_sss_11',
#  'hours_taught_11',
#  'teacher_salary_source_11',
#  'teacher_grade_level_11',
#  'concat_teacher_id_11',
#  'concat_teacher_id2_11',
#  'concat_teacher_id_new_11',
#  'teacherid_12',
#  'teacher_surname_12',
#  'teacher_name_12',
#  'new_teacher_12',
#  'teacher_nin_12',
#  'teacher_sex_12',
#  'teacher_time_12',
#  'teacher_age_12',
#  'teacher_payroll_num_12',
#  'teacher_current_position_12',
#  'teacher_current_position2_12',
#  'class_teacher_12',
#  'agetoservice_12',
#  'service_years_12',
#  'teacher_prof_qual_12',
#  'teacher_aca_qual_12',
#  'teacher_subj_specialty_pre_12',
#  'teacher_subj_specialty_pri_12',
#  'teacher_subj_specialty_jss_12',
#  'teacher_subj_specialty_sss_12',
#  'teacher_subj_taught_pre_12',
#  'teacher_subj_taught_pri_12',
#  'teacher_subj_taught_jss_12',
#  'teacher_subj_taught_sss_12',
#  'v1788',
#  'teacher_class_taught_primary_12',
#  'teacher_class_taught_jss_12',
#  'teacher_class_taught_sss_12',
#  'hours_taught_12',
#  'teacher_salary_source_12',
#  'teacher_grade_level_12',
#  'concat_teacher_id_12',
#  'concat_teacher_id2_12',
#  'concat_teacher_id_new_12',
#  'teacherid_13',
#  'teacher_surname_13',
#  'teacher_name_13',
#  'new_teacher_13',
#  'teacher_nin_13',
#  'teacher_sex_13',
#  'teacher_time_13',
#  'teacher_age_13',
#  'teacher_payroll_num_13',
#  'teacher_current_position_13',
#  'teacher_current_position2_13',
#  'class_teacher_13',
#  'agetoservice_13',
#  'service_years_13',
#  'teacher_prof_qual_13',
#  'teacher_aca_qual_13',
#  'teacher_subj_specialty_pre_13',
#  'teacher_subj_specialty_pri_13',
#  'teacher_subj_specialty_jss_13',
#  'teacher_subj_specialty_sss_13',
#  'teacher_subj_taught_pre_13',
#  'teacher_subj_taught_pri_13',
#  'teacher_subj_taught_jss_13',
#  'teacher_subj_taught_sss_13',
#  'v1826',
#  'teacher_class_taught_primary_13',
#  'teacher_class_taught_jss_13',
#  'teacher_class_taught_sss_13',
#  'hours_taught_13',
#  'teacher_salary_source_13',
#  'teacher_grade_level_13',
#  'concat_teacher_id_13',
#  'concat_teacher_id2_13',
#  'concat_teacher_id_new_13',
#  'teacherid_14',
#  'teacher_surname_14',
#  'teacher_name_14',
#  'new_teacher_14',
#  'teacher_nin_14',
#  'teacher_sex_14',
#  'teacher_time_14',
#  'teacher_age_14',
#  'teacher_payroll_num_14',
#  'teacher_current_position_14',
#  'teacher_current_position2_14',
#  'class_teacher_14',
#  'agetoservice_14',
#  'service_years_14',
#  'teacher_prof_qual_14',
#  'teacher_aca_qual_14',
#  'teacher_subj_specialty_pre_14',
#  'teacher_subj_specialty_pri_14',
#  'teacher_subj_specialty_jss_14',
#  'teacher_subj_specialty_sss_14',
#  'teacher_subj_taught_pre_14',
#  'teacher_subj_taught_pri_14',
#  'teacher_subj_taught_jss_14',
#  'teacher_subj_taught_sss_14',
#  'v1864',
#  'teacher_class_taught_primary_14',
#  'teacher_class_taught_jss_14',
#  'teacher_class_taught_sss_14',
#  'hours_taught_14',
#  'teacher_salary_source_14',
#  'teacher_grade_level_14',
#  'concat_teacher_id_14',
#  'concat_teacher_id2_14',
#  'concat_teacher_id_new_14',
#  'teacherid_15',
#  'teacher_surname_15',
#  'teacher_name_15',
#  'new_teacher_15',
#  'teacher_nin_15',
#  'teacher_sex_15',
#  'teacher_time_15',
#  'teacher_age_15',
#  'teacher_payroll_num_15',
#  'teacher_current_position_15',
#  'teacher_current_position2_15',
#  'class_teacher_15',
#  'agetoservice_15',
#  'service_years_15',
#  'teacher_prof_qual_15',
#  'teacher_aca_qual_15',
#  'teacher_subj_specialty_pre_15',
#  'teacher_subj_specialty_pri_15',
#  'teacher_subj_specialty_jss_15',
#  'teacher_subj_specialty_sss_15',
#  'teacher_subj_taught_pre_15',
#  'teacher_subj_taught_pri_15',
#  'teacher_subj_taught_jss_15',
#  'teacher_subj_taught_sss_15',
#  'v1902',
#  'teacher_class_taught_primary_15',
#  'teacher_class_taught_jss_15',
#  'teacher_class_taught_sss_15',
#  'hours_taught_15',
#  'teacher_salary_source_15',
#  'teacher_grade_level_15',
#  'concat_teacher_id_15',
#  'concat_teacher_id2_15',
#  'concat_teacher_id_new_15',
#  'teacherid_16',
#  'teacher_surname_16',
#  'teacher_name_16',
#  'new_teacher_16',
#  'teacher_nin_16',
#  'teacher_sex_16',
#  'teacher_time_16',
#  'teacher_age_16',
#  'teacher_payroll_num_16',
#  'teacher_current_position_16',
#  'teacher_current_position2_16',
#  'class_teacher_16',
#  'agetoservice_16',
#  'service_years_16',
#  'teacher_prof_qual_16',
#  'teacher_aca_qual_16',
#  'teacher_subj_specialty_pre_16',
#  'teacher_subj_specialty_pri_16',
#  'teacher_subj_specialty_jss_16',
#  'teacher_subj_specialty_sss_16',
#  'teacher_subj_taught_pre_16',
#  'teacher_subj_taught_pri_16',
#  'teacher_subj_taught_jss_16',
#  'teacher_subj_taught_sss_16',
#  'v1940',
#  'teacher_class_taught_primary_16',
#  'teacher_class_taught_jss_16',
#  'teacher_class_taught_sss_16',
#  'hours_taught_16',
#  'teacher_salary_source_16',
#  'teacher_grade_level_16',
#  'concat_teacher_id_16',
#  'concat_teacher_id2_16',
#  'concat_teacher_id_new_16',
#  'teacherid_17',
#  'teacher_surname_17',
#  'teacher_name_17',
#  'new_teacher_17',
#  'teacher_nin_17',
#  'teacher_sex_17',
#  'teacher_time_17',
#  'teacher_age_17',
#  'teacher_payroll_num_17',
#  'teacher_current_position_17',
#  'teacher_current_position2_17',
#  'class_teacher_17',
#  'agetoservice_17',
#  'service_years_17',
#  'teacher_prof_qual_17',
#  'teacher_aca_qual_17',
#  'teacher_subj_specialty_pre_17',
#  'teacher_subj_specialty_pri_17',
#  'teacher_subj_specialty_jss_17',
#  'teacher_subj_specialty_sss_17',
#  'teacher_subj_taught_pre_17',
#  'teacher_subj_taught_pri_17',
#  'teacher_subj_taught_jss_17',
#  'teacher_subj_taught_sss_17',
#  'v1978',
#  'teacher_class_taught_primary_17',
#  'teacher_class_taught_jss_17',
#  'teacher_class_taught_sss_17',
#  'hours_taught_17',
#  'teacher_salary_source_17',
#  'teacher_grade_level_17',
#  'concat_teacher_id_17',
#  'concat_teacher_id2_17',
#  'concat_teacher_id_new_17',
#  'teacherid_18',
#  'teacher_surname_18',
#  'teacher_name_18',
#  'new_teacher_18',
#  'teacher_nin_18',
#  'teacher_sex_18',
#  'teacher_time_18',
#  'teacher_age_18',
#  'teacher_payroll_num_18',
#  'teacher_current_position_18',
#  'teacher_current_position2_18',
#  'class_teacher_18',
#  'agetoservice_18',
#  'service_years_18',
#  'teacher_prof_qual_18',
#  'teacher_aca_qual_18',
#  'teacher_subj_specialty_pre_18',
#  'teacher_subj_specialty_pri_18',
#  'teacher_subj_specialty_jss_18',
#  'teacher_subj_specialty_sss_18',
#  'teacher_subj_taught_pre_18',
#  'teacher_subj_taught_pri_18',
#  'teacher_subj_taught_jss_18',
#  'teacher_subj_taught_sss_18',
#  'v2016',
#  'teacher_class_taught_primary_18',
#  'teacher_class_taught_jss_18',
#  'teacher_class_taught_sss_18',
#  'hours_taught_18',
#  'teacher_salary_source_18',
#  'teacher_grade_level_18',
#  'concat_teacher_id_18',
#  'concat_teacher_id2_18',
#  'concat_teacher_id_new_18',
#  'teacherid_19',
#  'teacher_surname_19',
#  'teacher_name_19',
#  'new_teacher_19',
#  'teacher_nin_19',
#  'teacher_sex_19',
#  'teacher_time_19',
#  'teacher_age_19',
#  'teacher_payroll_num_19',
#  'teacher_current_position_19',
#  'teacher_current_position2_19',
#  'class_teacher_19',
#  'agetoservice_19',
#  'service_years_19',
#  'teacher_prof_qual_19',
#  'teacher_aca_qual_19',
#  'teacher_subj_specialty_pre_19',
#  'teacher_subj_specialty_pri_19',
#  'teacher_subj_specialty_jss_19',
#  'teacher_subj_specialty_sss_19',
#  'teacher_subj_taught_pre_19',
#  'teacher_subj_taught_pri_19',
#  'teacher_subj_taught_jss_19',
#  'teacher_subj_taught_sss_19',
#  'v2054',
#  'teacher_class_taught_primary_19',
#  'teacher_class_taught_jss_19',
#  'teacher_class_taught_sss_19',
#  'hours_taught_19',
#  'teacher_salary_source_19',
#  'teacher_grade_level_19',
#  'concat_teacher_id_19',
#  'concat_teacher_id2_19',
#  'concat_teacher_id_new_19',
#  'teacherid_20',
#  'teacher_surname_20',
#  'teacher_name_20',
#  'new_teacher_20',
#  'teacher_nin_20',
#  'teacher_sex_20',
#  'teacher_time_20',
#  'teacher_age_20',
#  'teacher_payroll_num_20',
#  'teacher_current_position_20',
#  'teacher_current_position2_20',
#  'class_teacher_20',
#  'agetoservice_20',
#  'service_years_20',
#  'teacher_prof_qual_20',
#  'teacher_aca_qual_20',
#  'teacher_subj_specialty_pre_20',
#  'teacher_subj_specialty_pri_20',
#  'teacher_subj_specialty_jss_20',
#  'teacher_subj_specialty_sss_20',
#  'teacher_subj_taught_pre_20',
#  'teacher_subj_taught_pri_20',
#  'teacher_subj_taught_jss_20',
#  'teacher_subj_taught_sss_20',
#  'v2092',
#  'teacher_class_taught_primary_20',
#  'teacher_class_taught_jss_20',
#  'teacher_class_taught_sss_20',
#  'hours_taught_20',
#  'teacher_salary_source_20',
#  'teacher_grade_level_20',
#  'concat_teacher_id_20',
#  'concat_teacher_id2_20',
#  'concat_teacher_id_new_20',
#  'teacherid_21',
#  'teacher_surname_21',
#  'teacher_name_21',
#  'new_teacher_21',
#  'teacher_nin_21',
#  'teacher_sex_21',
#  'teacher_time_21',
#  'teacher_age_21',
#  'teacher_payroll_num_21',
#  'teacher_current_position_21',
#  'teacher_current_position2_21',
#  'class_teacher_21',
#  'agetoservice_21',
#  'service_years_21',
#  'teacher_prof_qual_21',
#  'teacher_aca_qual_21',
#  'teacher_subj_specialty_pre_21',
#  'teacher_subj_specialty_pri_21',
#  'teacher_subj_specialty_jss_21',
#  'teacher_subj_specialty_sss_21',
#  'teacher_subj_taught_pre_21',
#  'teacher_subj_taught_pri_21',
#  'teacher_subj_taught_jss_21',
#  'teacher_subj_taught_sss_21',
#  'v2130',
#  'teacher_class_taught_primary_21',
#  'teacher_class_taught_jss_21',
#  'teacher_class_taught_sss_21',
#  'hours_taught_21',
#  'teacher_salary_source_21',
#  'teacher_grade_level_21',
#  'concat_teacher_id_21',
#  'concat_teacher_id2_21',
#  'concat_teacher_id_new_21',
#  'teacherid_22',
#  'teacher_surname_22',
#  'teacher_name_22',
#  'new_teacher_22',
#  'teacher_nin_22',
#  'teacher_sex_22',
#  'teacher_time_22',
#  'teacher_age_22',
#  'teacher_payroll_num_22',
#  'teacher_current_position_22',
#  'teacher_current_position2_22',
#  'class_teacher_22',
#  'agetoservice_22',
#  'service_years_22',
#  'teacher_prof_qual_22',
#  'teacher_aca_qual_22',
#  'teacher_subj_specialty_pre_22',
#  'teacher_subj_specialty_pri_22',
#  'teacher_subj_specialty_jss_22',
#  'teacher_subj_specialty_sss_22',
#  'teacher_subj_taught_pre_22',
#  'teacher_subj_taught_pri_22',
#  'teacher_subj_taught_jss_22',
#  'teacher_subj_taught_sss_22',
#  'v2168',
# ...
#  'teacher_class_taught_sss_69',
#  'hours_taught_69',
#  'teacher_salary_source_69',
#  'teacher_grade_level_69',
#  'concat_teacher_id_69',
#  'concat_teacher_id2_69',
#  'concat_teacher_id_new_69',
#  'teacherid_70',
#  'teacher_surname_70',
#  'teacher_name_70',
#  'new_teacher_70',
#  'teacher_nin_70',
#  'teacher_sex_70',
#  'teacher_time_70',
#  'teacher_age_70',
#  'teacher_payroll_num_70',
#  'teacher_current_position_70',
#  'teacher_current_position2_70',
#  'class_teacher_70',
#  'agetoservice_70',
#  'service_years_70',
#  'teacher_prof_qual_70',
#  'teacher_aca_qual_70',
#  'teacher_subj_specialty_pre_70',
#  'teacher_subj_specialty_pri_70',
#  'teacher_subj_specialty_jss_70',
#  'teacher_subj_specialty_sss_70',
#  'teacher_subj_taught_pre_70',
#  'teacher_subj_taught_pri_70',
#  'teacher_subj_taught_jss_70',
#  'teacher_subj_taught_sss_70',
#  'v3992',
#  'teacher_class_taught_primary_70',
#  'teacher_class_taught_jss_70',
#  'teacher_class_taught_sss_70',
#  'hours_taught_70',
#  'teacher_salary_source_70',
#  'teacher_grade_level_70',
#  'concat_teacher_id_70',
#  'concat_teacher_id2_70',
#  'concat_teacher_id_new_70',
#  'teacherid_71',
#  'teacher_surname_71',
#  'teacher_name_71',
#  'new_teacher_71',
#  'teacher_nin_71',
#  'teacher_sex_71',
#  'teacher_time_71',
#  'teacher_age_71',
#  'teacher_payroll_num_71',
#  'teacher_current_position_71',
#  'teacher_current_position2_71',
#  'class_teacher_71',
#  'agetoservice_71',
#  'service_years_71',
#  'teacher_prof_qual_71',
#  'teacher_aca_qual_71',
#  'teacher_subj_specialty_pre_71',
#  'teacher_subj_specialty_pri_71',
#  'teacher_subj_specialty_jss_71',
#  'teacher_subj_specialty_sss_71',
#  'teacher_subj_taught_pre_71',
#  'teacher_subj_taught_pri_71',
#  'teacher_subj_taught_jss_71',
#  'teacher_subj_taught_sss_71',
#  'v4030',
#  'teacher_class_taught_primary_71',
#  'teacher_class_taught_jss_71',
#  'teacher_class_taught_sss_71',
#  'hours_taught_71',
#  'teacher_salary_source_71',
#  'teacher_grade_level_71',
#  'concat_teacher_id_71',
#  'concat_teacher_id2_71',
#  'concat_teacher_id_new_71',
#  'teacherid_72',
#  'teacher_surname_72',
#  'teacher_name_72',
#  'new_teacher_72',
#  'teacher_nin_72',
#  'teacher_sex_72',
#  'teacher_time_72',
#  'teacher_age_72',
#  'teacher_payroll_num_72',
#  'teacher_current_position_72',
#  'teacher_current_position2_72',
#  'class_teacher_72',
#  'agetoservice_72',
#  'service_years_72',
#  'teacher_prof_qual_72',
#  'teacher_aca_qual_72',
#  'teacher_subj_specialty_pre_72',
#  'teacher_subj_specialty_pri_72',
#  'teacher_subj_specialty_jss_72',
#  'teacher_subj_specialty_sss_72',
#  'teacher_subj_taught_pre_72',
#  'teacher_subj_taught_pri_72',
#  'teacher_subj_taught_jss_72',
#  'teacher_subj_taught_sss_72',
#  'v4068',
#  'teacher_class_taught_primary_72',
#  'teacher_class_taught_jss_72',
#  'teacher_class_taught_sss_72',
#  'hours_taught_72',
#  'teacher_salary_source_72',
#  'teacher_grade_level_72',
#  'concat_teacher_id_72',
#  'concat_teacher_id2_72',
#  'concat_teacher_id_new_72',
#  'teacherid_73',
#  'teacher_surname_73',
#  'teacher_name_73',
#  'new_teacher_73',
#  'teacher_nin_73',
#  'teacher_sex_73',
#  'teacher_time_73',
#  'teacher_age_73',
#  'teacher_payroll_num_73',
#  'teacher_current_position_73',
#  'teacher_current_position2_73',
#  'class_teacher_73',
#  'agetoservice_73',
#  'service_years_73',
#  'teacher_prof_qual_73',
#  'teacher_aca_qual_73',
#  'teacher_subj_specialty_pre_73',
#  'teacher_subj_specialty_pri_73',
#  'teacher_subj_specialty_jss_73',
#  'teacher_subj_specialty_sss_73',
#  'teacher_subj_taught_pre_73',
#  'teacher_subj_taught_pri_73',
#  'teacher_subj_taught_jss_73',
#  'teacher_subj_taught_sss_73',
#  'v4106',
#  'teacher_class_taught_primary_73',
#  'teacher_class_taught_jss_73',
#  'teacher_class_taught_sss_73',
#  'hours_taught_73',
#  'teacher_salary_source_73',
#  'teacher_grade_level_73',
#  'concat_teacher_id_73',
#  'concat_teacher_id2_73',
#  'concat_teacher_id_new_73',
#  'teacherid_74',
#  'teacher_surname_74',
#  'teacher_name_74',
#  'new_teacher_74',
#  'teacher_nin_74',
#  'teacher_sex_74',
#  'teacher_time_74',
#  'teacher_age_74',
#  'teacher_payroll_num_74',
#  'teacher_current_position_74',
#  'teacher_current_position2_74',
#  'class_teacher_74',
#  'agetoservice_74',
#  'service_years_74',
#  'teacher_prof_qual_74',
#  'teacher_aca_qual_74',
#  'teacher_subj_specialty_pre_74',
#  'teacher_subj_specialty_pri_74',
#  'teacher_subj_specialty_jss_74',
#  'teacher_subj_specialty_sss_74',
#  'teacher_subj_taught_pre_74',
#  'teacher_subj_taught_pri_74',
#  'teacher_subj_taught_jss_74',
#  'teacher_subj_taught_sss_74',
#  'v4144',
#  'teacher_class_taught_primary_74',
#  'teacher_class_taught_jss_74',
#  'teacher_class_taught_sss_74',
#  'hours_taught_74',
#  'teacher_salary_source_74',
#  'teacher_grade_level_74',
#  'concat_teacher_id_74',
#  'concat_teacher_id2_74',
#  'concat_teacher_id_new_74',
#  'teacherid_75',
#  'teacher_surname_75',
#  'teacher_name_75',
#  'new_teacher_75',
#  'teacher_nin_75',
#  'teacher_sex_75',
#  'teacher_time_75',
#  'teacher_age_75',
#  'teacher_payroll_num_75',
#  'teacher_current_position_75',
#  'teacher_current_position2_75',
#  'class_teacher_75',
#  'agetoservice_75',
#  'service_years_75',
#  'teacher_prof_qual_75',
#  'teacher_aca_qual_75',
#  'teacher_subj_specialty_pre_75',
#  'teacher_subj_specialty_pri_75',
#  'teacher_subj_specialty_jss_75',
#  'teacher_subj_specialty_sss_75',
#  'teacher_subj_taught_pre_75',
#  'teacher_subj_taught_pri_75',
#  'teacher_subj_taught_jss_75',
#  'teacher_subj_taught_sss_75',
#  'v4182',
#  'teacher_class_taught_primary_75',
#  'teacher_class_taught_jss_75',
#  'teacher_class_taught_sss_75',
#  'hours_taught_75',
#  'teacher_salary_source_75',
#  'teacher_grade_level_75',
#  'concat_teacher_id_75',
#  'concat_teacher_id2_75',
#  'concat_teacher_id_new_75',
#  'attendance_class1',
#  'attendance_class2',
#  'attendance_class3',
#  'attendance_class4',
#  'attendance_class5',
#  'attendance_class6',
#  'playg_image',
#  'watersource_image',
#  'latrines_image',
#  'comments',
#  'geopoint2latitude',
#  'geopoint2longitude',
#  'geopoint2altitude',
#  'geopoint2accuracy',
#  'comment_op',
#  'formdef_version',
#  'key',
#  'submissiondate',
#  'starttime',
#  'endtime'] (not in School schema)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filtering rows missing lat,lon...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filtering rows missing lat,lon -> before: 11188 rows, after filter: 10906 rows
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filter & validate each school row to the schema...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filter & validate each school row to the schema -> before: 10906 rows, after filter: 10906 rows
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:lookup GADM areas by lat,lon...
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:cache hit for: https://biogeo.ucdavis.edu/data/gadm3.6/gpkg/gadm36_SLE_gpkg.zip
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:converting geopackage file...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:processing each lat,lon into GADM area...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=METHODIST PRIMARY SCHOOL  (MOFINDOR SECTION SECTION, SAMBALU TOWN (8.335141 ; -10.60961), lat,lng=8.33522,-10.609630000000001 https://www.openstreetmap.org/#map=18/8.33522/-10.609630000000001 (uuid=a300ec9a-6c7f-4634-b5df-a6a2720f6dd4)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=METHODIST PRIMARY  (KIMANTADU SECTION, KUMATANDU TOWN (8.364089 ; -10.68654), lat,lng=8.364017,-10.68661 https://www.openstreetmap.org/#map=18/8.364017/-10.68661 (uuid=858fbf69-10b8-4117-9bb0-88acc391962d)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=METHODIST PRIMARY SCHOOL  (BULIMA SECTION, SENGEMA TOWN (8.299365 ; -10.70563), lat,lng=8.299811,-10.70546 https://www.openstreetmap.org/#map=18/8.299811/-10.70546 (uuid=b8dc0c71-ea7f-45db-887e-5e323daa8965)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=METHODIST PRIMARY SCHOOL  (NJAGOR SECTION, LALEHUN TOWN (8.421158 ; -10.65109), lat,lng=8.421097999999999,-10.65121 https://www.openstreetmap.org/#map=18/8.421097999999999/-10.65121 (uuid=f2721494-8050-4681-93b2-807e075950df)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=EVANGELICAL MODEL PRIMARY SCHOOL  (KENSAY SECTION, GBOGBORMA TOWN (8.778759 ; -10.52663), lat,lng=8.778837,-10.526689999999999 https://www.openstreetmap.org/#map=18/8.778837/-10.526689999999999 (uuid=a587f30b-6fbb-47bb-a537-6eb452ed7013)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=KONGOIFEH COMMUNITY PRIMARY SCHOOL  (KAMARA SECTION, KONGOIFEH TOWN (8.797207 ; -10.56449), lat,lng=8.797224,-10.56451 https://www.openstreetmap.org/#map=18/8.797224/-10.56451 (uuid=17f83881-65e1-43e0-a6c4-eeda134baca3)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=MASAKONDU COMMUNITY PRIMARY SCHOOL  (KAMARA SECTION, MASAKONDU TOWN (8.840248 ; -10.57453), lat,lng=8.840346,-10.57473 https://www.openstreetmap.org/#map=18/8.840346/-10.57473 (uuid=841fa0ba-03f0-4b85-9f67-1f5a9c86e4b1)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=ROMAN CATHOLIC PRIMARY  (MAFINDOR SECTION, YARDU TOWN (8.721643 ; -10.50674), lat,lng=8.721682000000001,-10.50662 https://www.openstreetmap.org/#map=18/8.721682000000001/-10.50662 (uuid=2db629ef-ff60-4f08-9719-0ea619d65807)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=ROMAN CATHOLIC PRIMARY SCHOOL  (MATTON SECTION, FODAYA TOWN (9.276823 ; -12.946), lat,lng=9.276709,-12.94608 https://www.openstreetmap.org/#map=18/9.276709/-12.94608 (uuid=a4fa6f0a-bdfd-4155-9e2f-e6e363ebaad0)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=COMMUNITY PRIMARY SCHOOL  (TAWUYA SECTION, MADINA LAYAH TOWN (9.110255 ; -12.9974), lat,lng=9.110289,-12.99731 https://www.openstreetmap.org/#map=18/9.110289/-12.99731 (uuid=ce2a9c91-7be1-41b5-9d74-76e2fb07d15e)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=KAMBIA DISTRICT COUNCIL PRIMARY SCHOOL  (TAWUYA SECTION, FUNKUDEH TOWN (9.132135 ; -12.99054), lat,lng=9.132106,-12.9905 https://www.openstreetmap.org/#map=18/9.132106/-12.9905 (uuid=8a1c5ce9-cc19-415f-9799-9adcb4b29728)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=MISSIONARY  CHURCH   OF  AFRICA   PRIMARY  SCHOOL  (UPPER  DELDUGU SECTION, SAMENDU TOWN (9.24341 ; -10.67237), lat,lng=9.244874000000001,-10.67235 https://www.openstreetmap.org/#map=18/9.244874000000001/-10.67235 (uuid=24af82c5-4482-4c39-92e4-a9192dedfd34)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:buffering location by 5.0km for school name=N.B.C. PRIMARY SCHOOL,  DALIPORTHOR  (THALLIA SECTION, DALIPORTHOR TOWN (9.997445 ; -11.79843), lat,lng=10.00008,-11.79923 https://www.openstreetmap.org/#map=18/10.00008/-11.79923 (uuid=34dbebac-25d2-4e49-938b-9326c3b0077e)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:readying pandas data types...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:done
#       country_code        admin0   admin1         admin2     admin3 admin4  \
# 0               SL  Sierra Leone  Eastern       Kailahun        Dia   None
# 1               SL  Sierra Leone  Eastern       Kailahun        Dia   None
# 2               SL  Sierra Leone  Eastern       Kailahun     Malema   None
# 3               SL  Sierra Leone  Eastern       Kailahun        Dia   None
# 4               SL  Sierra Leone  Eastern       Kailahun     Malema   None
# ...            ...           ...      ...            ...        ...    ...
# 11175           SL  Sierra Leone  Western  Western Urban  Freetown1   None
# 11176           SL  Sierra Leone  Western  Western Urban  Freetown1   None
# 11177           SL  Sierra Leone  Western  Western Urban  Freetown1   None
# 11178           SL  Sierra Leone  Western  Western Urban  Freetown1   None
# 11179           SL  Sierra Leone  Western  Western Urban  Freetown1   None
#
#         admin_code                   admin_id  \
# 0      SLE.1.1.1_1  3.6,SLE,GID_3=SLE.1.1.1_1
# 1      SLE.1.1.1_1  3.6,SLE,GID_3=SLE.1.1.1_1
# 2      SLE.1.1.7_1  3.6,SLE,GID_3=SLE.1.1.7_1
# 3      SLE.1.1.1_1  3.6,SLE,GID_3=SLE.1.1.1_1
# 4      SLE.1.1.7_1  3.6,SLE,GID_3=SLE.1.1.7_1
# ...            ...                        ...
# 11175  SLE.4.2.1_1  3.6,SLE,GID_3=SLE.4.2.1_1
# 11176  SLE.4.2.1_1  3.6,SLE,GID_3=SLE.4.2.1_1
# 11177  SLE.4.2.1_1  3.6,SLE,GID_3=SLE.4.2.1_1
# 11178  SLE.4.2.1_1  3.6,SLE,GID_3=SLE.4.2.1_1
# 11179  SLE.4.2.1_1  3.6,SLE,GID_3=SLE.4.2.1_1
#
#                                                     name address  ...  \
# 0      ALQUDUS ISLAMIC  PRIMARY SCHOOL  (SEINGA SECTI...    None  ...
# 1                       BADRUDEEN ISLAMIC PRIMARY SCHOOL    None  ...
# 2      COMMUNITY PRIMARY SCHOOL  (SIENGA SECTION, GBA...    None  ...
# 3      EARLY CHILDHOOD CARE AND DEVELOPMENT CENTRE  (...    None  ...
# 4      KAILAHUN  DISTRICT  EDUCATION  COUNCIL PRIMARY...    None  ...
# ...                                                  ...     ...  ...
# 11175  WILBERFORCE PRIMARY MUNICIPAL SCHOOL -  INFANT...    None  ...
# 11176  WILBERFORCE PRIMARY MUNICIPAL SCHOOL INFANTS  ...    None  ...
# 11177  WONDERLAND NURSERY AND PREPARATORY SCHOOL  (MU...    None  ...
# 11178  WONDERS INTERNATIONAL  ACADEMY PRESCHOOL  (HIL...    None  ...
# 11179  WONDERS INTERNATIONAL ACADEMY PREPARATORY SCHO...    None  ...
#
#       description last_update tower_dist tower_type_service tower_type  \
# 0            None        None       None               None       None
# 1            None        None       None               None       None
# 2            None        None       None               None       None
# 3            None        None       None               None       None
# 4            None        None       None               None       None
# ...           ...         ...        ...                ...        ...
# 11175        None        None       None               None       None
# 11176        None        None       None               None       None
# 11177        None        None       None               None       None
# 11178        None        None       None               None       None
# 11179        None        None       None               None       None
#
#        tower_code  tower_latitude  tower_longitude is_private  \
# 0            None            None             None       True
# 1            None            None             None       True
# 2            None            None             None       True
# 3            None            None             None       True
# 4            None            None             None       True
# ...           ...             ...              ...        ...
# 11175        None            None             None       True
# 11176        None            None             None       True
# 11177        None            None             None       True
# 11178        None            None             None       True
# 11179        None            None             None       True
#
#                                        uuid
# 0      757e76de-dfe6-49ca-8b11-2a9d190398f3
# 1      3727fe76-c67f-48c3-b65d-657616a9f27f
# 2      99fc22de-eeb7-46f1-b7c8-9849a7c09c35
# 3      24e02753-e447-406c-9182-fbf96c52fe83
# 4      891a61d9-5331-4cb4-b211-eb147b173163
# ...                                     ...
# 11175  e90c3b58-7775-4e93-b741-9aac7200a2ae
# 11176  1a48af34-46e7-4f03-9c7b-4d9beaa9ccc9
# 11177  7d71201e-0f2f-4c25-9f3d-24c5621d8a0d
# 11178  a960f6d2-50d1-4f71-b069-d385aafaf3a4
# 11179  eea8c118-4b83-44b4-aada-2ddac01b766d
#
# [10906 rows x 48 columns]

# %%
df.to_csv('sierra_leone_cleaned.csv', quoting=QUOTE_NONNUMERIC, index=False)

# %%
# open in LibreOffice, Excel, other
# !open sierra_leone_cleaned.csv
