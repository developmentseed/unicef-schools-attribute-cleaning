# %%
import logging
import pandas as pd
from pandas import Series
from iso3166 import countries
from csv import QUOTE_NONNUMERIC
from unicef_schools_attribute_cleaning.pandas.dataframe_cleaner import dataframe_cleaner

# make INFO logs visible
logging.basicConfig(level=logging.INFO)

# %%
src_df = pd.read_csv('../../data/UNICE_schools_raw_2020_Jun/rwandan_schools_gis_data_4g_coverage_status.csv', low_memory=False)
src_df
# Out:
#         NO        PROVINCE    DISTRICT   SECTOR       CELL     VILLAGE  \
# 0        1  City of Kigali  Nyarugenge   Gitega  Akabahizi  Iterambere
# 1        2  City of Kigali  Nyarugenge   Gitega  Akabahizi     Gihanga
# 2        3  City of Kigali  Nyarugenge   Gitega  Akabahizi  Iterambere
# 3        4  City of Kigali  Nyarugenge   Gitega   Kinyange     Uburezi
# 4        5  City of Kigali  Nyarugenge   Gitega       Kora      Kivumu
# ...    ...             ...         ...      ...        ...         ...
# 4229  4230        Northern      Burera  Rwerere  Gacundura   Gacundura
# 4230  4231        Northern      Burera  Rwerere    Gashoro     Rwerere
# 4231  4232        Northern      Burera  Rwerere    Gashoro       Cyapa
# 4232  4233        Northern      Burera  Rwerere   Ruconsho    Ruconsho
# 4233  4234        Northern      Burera  Rwerere     Rugali      Mucaca
#
#         School Name Settings in School PointID (GPS)   Degree  Minute  \
# 0      E.M CYAPEPE          Preprimary            049       1    56.0
# 1      E.M ITETERO          Preprimary            056       1    56.0
# 2       G.S CYAHAFI              9 YBE            048       1    56.0
# 3        E.P GITEGA            Primary            051       1    57.0
# 4      ETO MUHAZI I  Secondary A Level            047       1    57.0
# ...             ...                ...            ...     ...     ...
# 4229  E.P GACUNDURA            Primary             64       1    30.0
# 4230      G.S CYAPA             12 YBE             68       1    29.0
# 4231      E.M CYAPA         Preprimary            070       1    29.0
# 4232    E.P RWERERE            Primary             66       1    31.0
# 4233     E.P RUGALI            Primary             69       1    32.0
#
#       Seconds  Degree_2  Minute_2  Seconds_2          Description  \
# 0        41.5        30       3.0        7.8        School Center
# 1        56.1        30       3.0       12.7        School Center
# 2        41.0        30       3.0       12.0    NEAR THE ENTRANCE
# 3        35.2        30       3.0       22.7  HEAD TEACHER OFFICE
# 4         9.8        30       3.0       26.7  HEAD TEACHER OFFICE
# ...       ...       ...       ...        ...                  ...
# 4229      9.3        29      51.0       22.9            FLAG POLE
# 4230     50.7        29      51.0       47.4        School Center
# 4231     52.0        29      51.0       47.8        School Center
# 4232     47.0        29      52.0       55.0            FLAG POLE
# 4233     31.0        29      52.0       22.3        School Center
#
#                  Latitude           Longitude 4G Status
# 0     -1.9448611111111112   30.05216666666667   covered
# 1     -1.9489166666666666  30.053527777777777   covered
# 2     -1.9447222222222222  30.053333333333335   covered
# 3     -1.9597777777777776  30.056305555555557   covered
# 4      -1.952722222222222   30.05741666666667   covered
# ...                   ...                 ...       ...
# 4229  -1.5025833333333334  29.856361111111113   covered
# 4230  -1.4974166666666666  29.863166666666668   covered
# 4231  -1.4977777777777779   29.86327777777778   covered
# 4232  -1.5297222222222224  29.881944444444446   covered
# 4233  -1.5419444444444443   29.87286111111111   covered
#
# [4234 rows x 19 columns]

# %%
# Problem 1: there are 87 unique strings in the 'settings in school' column. 
# this poses a problem for what's supposed to be enumerated type for "EducationLevel" (primary, secondary) in the database, 
# however dataframe_cleaner's fuzzy matching enum will translate many of them 
src_df['Settings in School'].unique()
# Out:
# array(['Preprimary', '9 YBE', 'Primary', 'Secondary A Level', '12 YBE',
#        'Preprimary, 12 YBE', 'Preprimary, Primary ', 'Preprimary, 9 YBE',
#        'VCT', 'Secondary (O&A) Level', 'Secondary', 'Polytechnic',
#        'University', 'University ', 'VTC', 'Preprimary, Primary',
#        'Pre Primary only', nan, 'College', 'Secondary (O&A) Levels',
#        'VTC/TSS ', 'Technical', 'People with Disabilities', 'TVT', 'TSS',
#        'TVET', "Secondary A' level", 'Secondary (O&A) level',
#        'Secondary A level', ' TSS & VTC', 'Secondary  A Level',
#        'Primary ', 'Pre primary, Primary', 'Secondary (O&A)Level',
#        'Secondary (O&A)Levels', 'Preprimary ', 'TSS, VTC',
#        'Secondary ALevel', 'Secondary O Level', 'Prepramary', 'TSS &VTC',
#        'Secondary (O&A) Level ', 'Secondary, Short Courses', 'Institute',
#        'COLLEGE', 'TECHNICAL', '12YBE', '9YBE', 'School of Nursing',
#        'Preprimary , 12 YBE', "Secondary A'level", 'Preprimary , 9 YBE',
#        'Pre primary', 'Secondary(O&A) Levels', 'Secondary( O&A) Levels',
#        'Prerimary, 12 YBE', 'Prerimary, 9 YBE', 'TSS & VTC', 'Prerimary',
#        'Polytechnic, TSS', 'Preprimary, VTC', 'Secondary (A&O) level',
#        "A'LEVEL", "Preprimary, Secondary O' level",
#        'Secondary (O&A) LEVEL', 'Secondary O level', 'Preprimary,9 YBE',
#        'Short Course', 'Secondary, Short Course', 'Prerimary, Primary',
#        'VTC/TSS', 'Short Courses', 'INSTITUTE', 'SCHOOL OF NURSING ',
#        'Secondary (O+A) Levels', 'SCHOOL OF NURSING', 'Pre Primary',
#        'Secondary A', 'Secondary (A&O) Level',
#        'Primary, Secondary O Level', '12BYE', 'Secondary (A&O) Levels',
#        'Preprimary,Primary', 'Secondary,  Short Courses',
#        'Primary, Secondary (O&A) Levels', 'primary',
#        'Secondary(O&A) levels'], dtype=object)

# %%
# Problem 2: the connectivity type (4G) is encoded in the column name, not in field values.
# The dataframe_cleaner does not support this. We must manually pre-process with pandas.
src_df['4G Status'].unique()
# Out:
# array(['covered', 'Not covered'], dtype=object)

# %%
# manual pandas workaround for problem 2: create a pandas function to move the 4g status into field values
def _4g_updater(row: Series) -> Series:
    _4g_status = row['4G Status'].lower()
    result = Series(data=row)
    if _4g_status == "covered":
        result['connectivity'] = True
        result['type_connectivity'] = '4G'
        result['tower_type_service'] = '4G'
    elif _4g_status == "not covered":
        result['connectivity'] = False
        result['type_connectivity'] = None
        result['tower_type_service'] = None
    return result

preprocessed_df = src_df.apply(_4g_updater, axis=1)
preprocessed_df[['4G Status', 'connectivity', 'type_connectivity', 'tower_type_service']]
# Out:
#      4G Status  connectivity type_connectivity tower_type_service
# 0      covered          True                4G                 4G
# 1      covered          True                4G                 4G
# 2      covered          True                4G                 4G
# 3      covered          True                4G                 4G
# 4      covered          True                4G                 4G
# ...        ...           ...               ...                ...
# 4229   covered          True                4G                 4G
# 4230   covered          True                4G                 4G
# 4231   covered          True                4G                 4G
# 4232   covered          True                4G                 4G
# 4233   covered          True                4G                 4G
#
# [4234 rows x 4 columns]

# %%
# run the dataframe_cleaner
country = countries.get('RW')
df = dataframe_cleaner(
    dataframe=preprocessed_df, 
    country=country,
    is_private=True,
    provider="unicef",
    provider_is_private=True
)
# Out:
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:copying dataframe...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:standardizing column names...
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:uuid column not found, generating uuid4
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:renaming columns: {'DISTRICT': ('admin3', 'alias exact match'),
#  'Description': ('description', 'fuzzy match 100%'),
#  'Latitude': ('lat', 'alias exact match'),
#  'Longitude': ('lon', 'alias exact match'),
#  'PROVINCE': ('admin2', 'alias exact match'),
#  'School Name': ('name', 'fuzzy match 90%'),
#  'Settings in School': ('educ_level', 'alias exact match')}
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:adding 33 columns from schema: ['admin0',
#  'admin1',
#  'admin4',
#  'admin_code',
#  'admin_id',
#  'address',
#  'address2',
#  'phone_number',
#  'person_contact',
#  'email',
#  'postal_code',
#  'altitude',
#  'gps_confidence',
#  'date',
#  'num_students',
#  'num_teachers',
#  'speed_connectivity',
#  'latency_connectivity',
#  'availability_connectivity',
#  'num_computers',
#  'type_school',
#  'environment',
#  'num_classrooms',
#  'num_sections',
#  'water',
#  'electricity',
#  'num_latrines',
#  'last_update',
#  'tower_dist',
#  'tower_type',
#  'tower_code',
#  'tower_latitude',
#  'tower_longitude']
# INFO:unicef_schools_attribute_cleaning.pandas.standardize_column_names:removing columns: ['NO',
#  'SECTOR',
#  'CELL',
#  'VILLAGE',
#  'PointID (GPS) ',
#  'Degree',
#  'Minute',
#  'Seconds',
#  'Degree_2',
#  'Minute_2',
#  'Seconds_2',
#  '4G Status'] (not in School schema)
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filtering rows missing lat,lon...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filtering rows missing lat,lon -> 4234 rows, after filter: 4233 rows
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filter & validate each school row to the schema...
# WARNING:unicef_schools_attribute_cleaning.models.FuzzyMatchingEnum.EducationLevel:<aenum 'EducationLevel'> has no fuzzy match for 'Short Course', choices = ['pre_primary', 'pre_básica', 'primary', 'básica', 'middle', 'media', 'secondary', '_9_ybe', '_12_ybe', 'a_level', 'b_level', 'polytechnic', 'college', 'university', 'technical', 'vocational', 'vtc', 'tss', 'disability', 'nursing']
# WARNING:unicef_schools_attribute_cleaning.models.FuzzyMatchingEnum.EducationLevel:<aenum 'EducationLevel'> has no fuzzy match for 'Short Course', choices = ['pre_primary', 'pre_básica', 'primary', 'básica', 'middle', 'media', 'secondary', '_9_ybe', '_12_ybe', 'a_level', 'b_level', 'polytechnic', 'college', 'university', 'technical', 'vocational', 'vtc', 'tss', 'disability', 'nursing']
# WARNING:unicef_schools_attribute_cleaning.models.FuzzyMatchingEnum.EducationLevel:<aenum 'EducationLevel'> has no fuzzy match for 'Short Courses', choices = ['pre_primary', 'pre_básica', 'primary', 'básica', 'middle', 'media', 'secondary', '_9_ybe', '_12_ybe', 'a_level', 'b_level', 'polytechnic', 'college', 'university', 'technical', 'vocational', 'vtc', 'tss', 'disability', 'nursing']
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:filter & validate each school row to the schema -> before: 4233 rows, after filter: 4233 rows
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:lookup GADM areas by lat,lon...
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:cache hit for: https://biogeo.ucdavis.edu/data/gadm3.6/gpkg/gadm36_RWA_gpkg.zip
# INFO:unicef_schools_attribute_cleaning.geocoding.GADMLoader:converting geopackage file...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:processing each lat,lon...
# INFO:unicef_schools_attribute_cleaning.pandas.dataframe_cleaner:readying pandas data types...

# %%
df.to_csv('rwanda_cleaned.csv', quoting=QUOTE_NONNUMERIC, index=False)

# %%
# open in LibreOffice, Excel, other
# !open rwanda_cleaned.csv
